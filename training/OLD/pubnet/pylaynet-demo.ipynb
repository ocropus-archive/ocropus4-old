# %%
# %pylab
# Out:
# Using matplotlib backend: GTK3Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
import webdataset as wds

# %%
ds = wds.WebDataset("http://storage.googleapis.com/lpr-publaynet/publaynet-train-{000000..000019}.tar").decode("rgb8")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fd69964805f5> in <module>
# ----> 1 ds = wds.WebDataset("http://storage.googleapis.com/lpr-publaynet/publaynet-train-{000000..000019}.tar").decode("rgb8")
#
# NameError: name 'wds' is not defined

# %%
src = iter(ds)
