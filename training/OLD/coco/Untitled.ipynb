# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import csv

# %%
size1 = list(csv.reader(open("size1")))[2:]
size2 = list(csv.reader(open("size2")))[2:]
size2[:10]
# Out:
# [['177', '44'],
#  ['87', '32'],
#  ['169', '56'],
#  ['174', '50'],
#  ['120', '47'],
#  ['100', '42'],
#  ['85', '40'],
#  ['245', '73'],
#  ['64', '31'],
#  ['117', '42']]

# %%
size1 = [[int(x) for x in l] for l in size1]
size2 = [[int(x) for x in l] for l in size2]

# %%
size1 = array(size1)
size2 = array(size2)

# %%
figsize(12, 8)
scatter(size1[:, 0], size1[:, 1], alpha=0.1)
scatter(size2[:, 0], size2[:, 1], alpha=0.1)
