# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import torch
from torch import nn
import copy

# %%
l = nn.Linear(3, 3)
l2 = copy.copy(l)
l3 = copy.deepcopy(l)
l4 = l.to("cuda:0")
l5 = l4.to("cuda:1")

# %%
next(l.parameters())[0,0]
