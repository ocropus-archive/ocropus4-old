# %%
gsutil -m rm gs://lpr-temp/* > log 2>&1 || true
tail log
# Out:
# Removing gs://lpr-temp/Volume_0066-seg.tgz...
# Removing gs://lpr-temp/Volume_0067-seg.tgz...
# Removing gs://lpr-temp/Volume_0068-seg.tgz...
# Removing gs://lpr-temp/Volume_0069-seg.tgz...
# Removing gs://lpr-temp/Volume_0070-seg.tgz...
# Removing gs://lpr-temp/Volume_0071-seg.tgz...
# Removing gs://lpr-temp/Volume_0072-seg.tgz...
# Removing gs://lpr-temp/Volume_0073-seg.tgz...
# / [73/73 objects] 100% Done
# Operation completed over 73 objects.

# %%
src=gs://lpr-g1000-tess
dst=gs://lpr-temp
out=gs://lpr-g1000-seg

# %%
kubectl delete jobs --all 2>&1 | tail 
kubectl delete pods --all 2>&1 | tail
kubectl delete services shuffle || true
# Out:
# job.batch "mapper1" deleted
# job.batch "mapper2" deleted
# job.batch "mapper3" deleted
# No resources found
# service "shuffle" deleted

# %%
cat > kubetpl.yaml <<'EOF'
image: gcr.io/research-191823/simple
memory: 8G
app: shuffle
subdomain: shuffle
EOF

# %%
kubetpl service | kubectl apply -f -
# Out:
# service/shuffle created

# %%
gsutil ls $src | fgrep .tgz | cat -n | 
while read index src; do
base=$(basename $src .tgz)
echo $index $src $base
kubetpl job -L jobgroup=mapper -M 8G -I gcr.io/research-191823/simple -n mapper$index -c "
python3 /files/hocr2seg $src /dev/stdout | gsutil cp - $dst/$base-seg.tgz
" | kubectl apply -f -
done
# Out:
# 1 gs://lpr-g1000-tess/Volume_0000.tgz Volume_0000
# job.batch/mapper1 created
# 2 gs://lpr-g1000-tess/Volume_0001.tgz Volume_0001
# job.batch/mapper2 created
# 3 gs://lpr-g1000-tess/Volume_0002.tgz Volume_0002
# job.batch/mapper3 created
# 4 gs://lpr-g1000-tess/Volume_0003.tgz Volume_0003
# job.batch/mapper4 created
# 5 gs://lpr-g1000-tess/Volume_0004.tgz Volume_0004
# job.batch/mapper5 created
# 6 gs://lpr-g1000-tess/Volume_0005.tgz Volume_0005
# job.batch/mapper6 created
# 7 gs://lpr-g1000-tess/Volume_0006.tgz Volume_0006
# job.batch/mapper7 created
# 8 gs://lpr-g1000-tess/Volume_0007.tgz Volume_0007
# job.batch/mapper8 created
# 9 gs://lpr-g1000-tess/Volume_0008.tgz Volume_0008
# job.batch/mapper9 created
# 10 gs://lpr-g1000-tess/Volume_0009.tgz Volume_0009
# job.batch/mapper10 created
# 11 gs://lpr-g1000-tess/Volume_0010.tgz Volume_0010
# job.batch/mapper11 created
# 12 gs://lpr-g1000-tess/Volume_0011.tgz Volume_0011
# job.batch/mapper12 created
# 13 gs://lpr-g1000-tess/Volume_0012.tgz Volume_0012
# job.batch/mapper13 created
# 14 gs://lpr-g1000-tess/Volume_0013.tgz Volume_0013
# job.batch/mapper14 created
# 15 gs://lpr-g1000-tess/Volume_0014.tgz Volume_0014
# job.batch/mapper15 created
# 16 gs://lpr-g1000-tess/Volume_0015.tgz Volume_0015
# job.batch/mapper16 created
# 17 gs://lpr-g1000-tess/Volume_0016.tgz Volume_0016
# job.batch/mapper17 created
# 18 gs://lpr-g1000-tess/Volume_0017.tgz Volume_0017
# job.batch/mapper18 created
# 19 gs://lpr-g1000-tess/Volume_0018.tgz Volume_0018
# job.batch/mapper19 created
# 20 gs://lpr-g1000-tess/Volume_0019.tgz Volume_0019
# job.batch/mapper20 created
# 21 gs://lpr-g1000-tess/Volume_0020.tgz Volume_0020
# job.batch/mapper21 created
# 22 gs://lpr-g1000-tess/Volume_0021.tgz Volume_0021
# job.batch/mapper22 created
# 23 gs://lpr-g1000-tess/Volume_0022.tgz Volume_0022
# job.batch/mapper23 created
# 24 gs://lpr-g1000-tess/Volume_0023.tgz Volume_0023
# job.batch/mapper24 created
# 25 gs://lpr-g1000-tess/Volume_0024.tgz Volume_0024
# job.batch/mapper25 created
# 26 gs://lpr-g1000-tess/Volume_0025.tgz Volume_0025
# job.batch/mapper26 created
# 27 gs://lpr-g1000-tess/Volume_0026.tgz Volume_0026
# job.batch/mapper27 created
# 28 gs://lpr-g1000-tess/Volume_0027.tgz Volume_0027
# job.batch/mapper28 created
# 29 gs://lpr-g1000-tess/Volume_0028.tgz Volume_0028
# job.batch/mapper29 created
# 30 gs://lpr-g1000-tess/Volume_0029.tgz Volume_0029
# job.batch/mapper30 created
# 31 gs://lpr-g1000-tess/Volume_0030.tgz Volume_0030
# job.batch/mapper31 created
# 32 gs://lpr-g1000-tess/Volume_0031.tgz Volume_0031
# job.batch/mapper32 created
# 33 gs://lpr-g1000-tess/Volume_0032.tgz Volume_0032
# job.batch/mapper33 created
# 34 gs://lpr-g1000-tess/Volume_0033.tgz Volume_0033
# job.batch/mapper34 created
# 35 gs://lpr-g1000-tess/Volume_0034.tgz Volume_0034
# job.batch/mapper35 created
# 36 gs://lpr-g1000-tess/Volume_0035.tgz Volume_0035
# job.batch/mapper36 created
# 37 gs://lpr-g1000-tess/Volume_0036.tgz Volume_0036
# job.batch/mapper37 created
# 38 gs://lpr-g1000-tess/Volume_0037.tgz Volume_0037
# job.batch/mapper38 created
# 39 gs://lpr-g1000-tess/Volume_0038.tgz Volume_0038
# job.batch/mapper39 created
# 40 gs://lpr-g1000-tess/Volume_0039.tgz Volume_0039
# job.batch/mapper40 created
# 41 gs://lpr-g1000-tess/Volume_0040.tgz Volume_0040
# job.batch/mapper41 created
# 42 gs://lpr-g1000-tess/Volume_0041.tgz Volume_0041
# job.batch/mapper42 created
# 43 gs://lpr-g1000-tess/Volume_0042.tgz Volume_0042
# job.batch/mapper43 created
# 44 gs://lpr-g1000-tess/Volume_0043.tgz Volume_0043
# job.batch/mapper44 created
# 45 gs://lpr-g1000-tess/Volume_0044.tgz Volume_0044
# job.batch/mapper45 created
# 46 gs://lpr-g1000-tess/Volume_0045.tgz Volume_0045
# job.batch/mapper46 created
# 47 gs://lpr-g1000-tess/Volume_0046.tgz Volume_0046
# job.batch/mapper47 created
# 48 gs://lpr-g1000-tess/Volume_0047.tgz Volume_0047
# job.batch/mapper48 created
# 49 gs://lpr-g1000-tess/Volume_0048.tgz Volume_0048
# job.batch/mapper49 created
# 50 gs://lpr-g1000-tess/Volume_0049.tgz Volume_0049
# job.batch/mapper50 created
# 51 gs://lpr-g1000-tess/Volume_0050.tgz Volume_0050
# job.batch/mapper51 created
# 52 gs://lpr-g1000-tess/Volume_0051.tgz Volume_0051
# job.batch/mapper52 created
# 53 gs://lpr-g1000-tess/Volume_0052.tgz Volume_0052
# job.batch/mapper53 created
# 54 gs://lpr-g1000-tess/Volume_0053.tgz Volume_0053
# job.batch/mapper54 created
# 55 gs://lpr-g1000-tess/Volume_0054.tgz Volume_0054
# job.batch/mapper55 created
# 56 gs://lpr-g1000-tess/Volume_0055.tgz Volume_0055
# job.batch/mapper56 created
# 57 gs://lpr-g1000-tess/Volume_0056.tgz Volume_0056
# job.batch/mapper57 created
# 58 gs://lpr-g1000-tess/Volume_0057.tgz Volume_0057
# job.batch/mapper58 created
# 59 gs://lpr-g1000-tess/Volume_0058.tgz Volume_0058
# job.batch/mapper59 created
# 60 gs://lpr-g1000-tess/Volume_0059.tgz Volume_0059
# job.batch/mapper60 created
# 61 gs://lpr-g1000-tess/Volume_0060.tgz Volume_0060
# job.batch/mapper61 created
# 62 gs://lpr-g1000-tess/Volume_0061.tgz Volume_0061
# job.batch/mapper62 created
# 63 gs://lpr-g1000-tess/Volume_0062.tgz Volume_0062
# job.batch/mapper63 created
# 64 gs://lpr-g1000-tess/Volume_0063.tgz Volume_0063
# job.batch/mapper64 created
# 65 gs://lpr-g1000-tess/Volume_0064.tgz Volume_0064
# job.batch/mapper65 created
# 66 gs://lpr-g1000-tess/Volume_0065.tgz Volume_0065
# job.batch/mapper66 created
# 67 gs://lpr-g1000-tess/Volume_0066.tgz Volume_0066
# job.batch/mapper67 created
# 68 gs://lpr-g1000-tess/Volume_0067.tgz Volume_0067
# job.batch/mapper68 created
# 69 gs://lpr-g1000-tess/Volume_0068.tgz Volume_0068
# job.batch/mapper69 created
# 70 gs://lpr-g1000-tess/Volume_0069.tgz Volume_0069
# job.batch/mapper70 created
# 71 gs://lpr-g1000-tess/Volume_0070.tgz Volume_0070
# job.batch/mapper71 created
# 72 gs://lpr-g1000-tess/Volume_0071.tgz Volume_0071
# job.batch/mapper72 created
# 73 gs://lpr-g1000-tess/Volume_0072.tgz Volume_0072
# job.batch/mapper73 created
# 74 gs://lpr-g1000-tess/Volume_0073.tgz Volume_0073
# job.batch/mapper74 created
# 75 gs://lpr-g1000-tess/Volume_0074.tgz Volume_0074
# job.batch/mapper75 created
# 76 gs://lpr-g1000-tess/Volume_0075.tgz Volume_0075
# job.batch/mapper76 created
# 77 gs://lpr-g1000-tess/Volume_0076.tgz Volume_0076
# job.batch/mapper77 created
# 78 gs://lpr-g1000-tess/Volume_0077.tgz Volume_0077
# job.batch/mapper78 created
# 79 gs://lpr-g1000-tess/Volume_0078.tgz Volume_0078
# job.batch/mapper79 created
# 80 gs://lpr-g1000-tess/Volume_0079.tgz Volume_0079
# job.batch/mapper80 created
# 81 gs://lpr-g1000-tess/Volume_0080.tgz Volume_0080
# job.batch/mapper81 created
# 82 gs://lpr-g1000-tess/Volume_0081.tgz Volume_0081
# job.batch/mapper82 created
# 83 gs://lpr-g1000-tess/Volume_0082.tgz Volume_0082
# job.batch/mapper83 created
# 84 gs://lpr-g1000-tess/Volume_0083.tgz Volume_0083
# job.batch/mapper84 created
# 85 gs://lpr-g1000-tess/Volume_0084.tgz Volume_0084
# job.batch/mapper85 created
# 86 gs://lpr-g1000-tess/Volume_0085.tgz Volume_0085
# job.batch/mapper86 created
# 87 gs://lpr-g1000-tess/Volume_0086.tgz Volume_0086
# job.batch/mapper87 created
# 88 gs://lpr-g1000-tess/Volume_0087.tgz Volume_0087
# job.batch/mapper88 created
# 89 gs://lpr-g1000-tess/Volume_0088.tgz Volume_0088
# job.batch/mapper89 created
# 90 gs://lpr-g1000-tess/Volume_0089.tgz Volume_0089
# job.batch/mapper90 created
# 91 gs://lpr-g1000-tess/Volume_0090.tgz Volume_0090
# job.batch/mapper91 created
# 92 gs://lpr-g1000-tess/Volume_0091.tgz Volume_0091
# job.batch/mapper92 created
# 93 gs://lpr-g1000-tess/Volume_0092.tgz Volume_0092
# job.batch/mapper93 created
# 94 gs://lpr-g1000-tess/Volume_0093.tgz Volume_0093
# job.batch/mapper94 created
# 95 gs://lpr-g1000-tess/Volume_0094.tgz Volume_0094
# job.batch/mapper95 created
# 96 gs://lpr-g1000-tess/Volume_0095.tgz Volume_0095
# job.batch/mapper96 created
# 97 gs://lpr-g1000-tess/Volume_0096.tgz Volume_0096
# job.batch/mapper97 created
# 98 gs://lpr-g1000-tess/Volume_0097.tgz Volume_0097
# job.batch/mapper98 created
# 99 gs://lpr-g1000-tess/Volume_0098.tgz Volume_0098
# job.batch/mapper99 created
# 100 gs://lpr-g1000-tess/Volume_0099.tgz Volume_0099
# job.batch/mapper100 created
# 101 gs://lpr-g1000-tess/Volume_0100.tgz Volume_0100
# job.batch/mapper101 created
# 102 gs://lpr-g1000-tess/Volume_0101.tgz Volume_0101
# job.batch/mapper102 created
# 103 gs://lpr-g1000-tess/Volume_0102.tgz Volume_0102
# job.batch/mapper103 created
# 104 gs://lpr-g1000-tess/Volume_0103.tgz Volume_0103
# job.batch/mapper104 created
# 105 gs://lpr-g1000-tess/Volume_0104.tgz Volume_0104
# job.batch/mapper105 created
# 106 gs://lpr-g1000-tess/Volume_0105.tgz Volume_0105
# job.batch/mapper106 created
# 107 gs://lpr-g1000-tess/Volume_0106.tgz Volume_0106
# job.batch/mapper107 created
# 108 gs://lpr-g1000-tess/Volume_0107.tgz Volume_0107
# job.batch/mapper108 created
# 109 gs://lpr-g1000-tess/Volume_0108.tgz Volume_0108
# job.batch/mapper109 created
# 110 gs://lpr-g1000-tess/Volume_0109.tgz Volume_0109
# job.batch/mapper110 created
# 111 gs://lpr-g1000-tess/Volume_0110.tgz Volume_0110
# job.batch/mapper111 created
# 112 gs://lpr-g1000-tess/Volume_0111.tgz Volume_0111
# job.batch/mapper112 created
# 113 gs://lpr-g1000-tess/Volume_0112.tgz Volume_0112
# job.batch/mapper113 created
# 114 gs://lpr-g1000-tess/Volume_0113.tgz Volume_0113
# job.batch/mapper114 created
# 115 gs://lpr-g1000-tess/Volume_0114.tgz Volume_0114
# job.batch/mapper115 created
# 116 gs://lpr-g1000-tess/Volume_0115.tgz Volume_0115
# job.batch/mapper116 created
# 117 gs://lpr-g1000-tess/Volume_0116.tgz Volume_0116
# job.batch/mapper117 created
# 118 gs://lpr-g1000-tess/Volume_0117.tgz Volume_0117
# job.batch/mapper118 created
# 119 gs://lpr-g1000-tess/Volume_0118.tgz Volume_0118
# job.batch/mapper119 created
# 120 gs://lpr-g1000-tess/Volume_0119.tgz Volume_0119
# job.batch/mapper120 created
# 121 gs://lpr-g1000-tess/Volume_0120.tgz Volume_0120
# job.batch/mapper121 created
# 122 gs://lpr-g1000-tess/Volume_0121.tgz Volume_0121
# job.batch/mapper122 created
# 123 gs://lpr-g1000-tess/Volume_0122.tgz Volume_0122
# job.batch/mapper123 created
# 124 gs://lpr-g1000-tess/Volume_0123.tgz Volume_0123
# job.batch/mapper124 created
# 125 gs://lpr-g1000-tess/Volume_0124.tgz Volume_0124
# job.batch/mapper125 created
# 126 gs://lpr-g1000-tess/Volume_0125.tgz Volume_0125
# job.batch/mapper126 created
# 127 gs://lpr-g1000-tess/Volume_0126.tgz Volume_0126
# job.batch/mapper127 created
# 128 gs://lpr-g1000-tess/Volume_0127.tgz Volume_0127
# job.batch/mapper128 created
# 129 gs://lpr-g1000-tess/Volume_0128.tgz Volume_0128
# job.batch/mapper129 created
# 130 gs://lpr-g1000-tess/Volume_0129.tgz Volume_0129
# job.batch/mapper130 created
# 131 gs://lpr-g1000-tess/Volume_0130.tgz Volume_0130
# job.batch/mapper131 created
# 132 gs://lpr-g1000-tess/Volume_0131.tgz Volume_0131
# job.batch/mapper132 created
# 133 gs://lpr-g1000-tess/Volume_0132.tgz Volume_0132
# job.batch/mapper133 created
# 134 gs://lpr-g1000-tess/Volume_0133.tgz Volume_0133
# job.batch/mapper134 created
# 135 gs://lpr-g1000-tess/Volume_0134.tgz Volume_0134
# job.batch/mapper135 created
# 136 gs://lpr-g1000-tess/Volume_0135.tgz Volume_0135
# job.batch/mapper136 created
# 137 gs://lpr-g1000-tess/Volume_0136.tgz Volume_0136
# job.batch/mapper137 created
# 138 gs://lpr-g1000-tess/Volume_0137.tgz Volume_0137
# job.batch/mapper138 created
# 139 gs://lpr-g1000-tess/Volume_0138.tgz Volume_0138
# job.batch/mapper139 created
# 140 gs://lpr-g1000-tess/Volume_0139.tgz Volume_0139
# job.batch/mapper140 created
# 141 gs://lpr-g1000-tess/Volume_0140.tgz Volume_0140
# job.batch/mapper141 created
# 142 gs://lpr-g1000-tess/Volume_0141.tgz Volume_0141
# job.batch/mapper142 created
# 143 gs://lpr-g1000-tess/Volume_0142.tgz Volume_0142
# job.batch/mapper143 created
# 144 gs://lpr-g1000-tess/Volume_0143.tgz Volume_0143
# job.batch/mapper144 created
# 145 gs://lpr-g1000-tess/Volume_0144.tgz Volume_0144
# job.batch/mapper145 created
# 146 gs://lpr-g1000-tess/Volume_0145.tgz Volume_0145
# job.batch/mapper146 created
# 147 gs://lpr-g1000-tess/Volume_0146.tgz Volume_0146
# job.batch/mapper147 created
# 148 gs://lpr-g1000-tess/Volume_0147.tgz Volume_0147
# job.batch/mapper148 created
# 149 gs://lpr-g1000-tess/Volume_0148.tgz Volume_0148
# job.batch/mapper149 created
# 150 gs://lpr-g1000-tess/Volume_0149.tgz Volume_0149
# job.batch/mapper150 created
# 151 gs://lpr-g1000-tess/Volume_0150.tgz Volume_0150
# job.batch/mapper151 created
# 152 gs://lpr-g1000-tess/Volume_0151.tgz Volume_0151
# job.batch/mapper152 created
# 153 gs://lpr-g1000-tess/Volume_0152.tgz Volume_0152
# job.batch/mapper153 created
# 154 gs://lpr-g1000-tess/Volume_0153.tgz Volume_0153
# job.batch/mapper154 created
# 155 gs://lpr-g1000-tess/Volume_0154.tgz Volume_0154
# job.batch/mapper155 created
# 156 gs://lpr-g1000-tess/Volume_0155.tgz Volume_0155
# job.batch/mapper156 created
# 157 gs://lpr-g1000-tess/Volume_0156.tgz Volume_0156
# job.batch/mapper157 created
# 158 gs://lpr-g1000-tess/Volume_0157.tgz Volume_0157
# job.batch/mapper158 created
# 159 gs://lpr-g1000-tess/Volume_0158.tgz Volume_0158
# job.batch/mapper159 created
# 160 gs://lpr-g1000-tess/Volume_0159.tgz Volume_0159
# job.batch/mapper160 created
# 161 gs://lpr-g1000-tess/Volume_0160.tgz Volume_0160
# job.batch/mapper161 created
# 162 gs://lpr-g1000-tess/Volume_0161.tgz Volume_0161
# job.batch/mapper162 created
# 163 gs://lpr-g1000-tess/Volume_0162.tgz Volume_0162
# job.batch/mapper163 created
# 164 gs://lpr-g1000-tess/Volume_0163.tgz Volume_0163
# job.batch/mapper164 created
# 165 gs://lpr-g1000-tess/Volume_0164.tgz Volume_0164
# job.batch/mapper165 created
# 166 gs://lpr-g1000-tess/Volume_0165.tgz Volume_0165
# job.batch/mapper166 created
# 167 gs://lpr-g1000-tess/Volume_0166.tgz Volume_0166
# job.batch/mapper167 created
# 168 gs://lpr-g1000-tess/Volume_0167.tgz Volume_0167
# job.batch/mapper168 created
# 169 gs://lpr-g1000-tess/Volume_0168.tgz Volume_0168
# job.batch/mapper169 created
# 170 gs://lpr-g1000-tess/Volume_0169.tgz Volume_0169
# job.batch/mapper170 created
# 171 gs://lpr-g1000-tess/Volume_0170.tgz Volume_0170
# job.batch/mapper171 created
# 172 gs://lpr-g1000-tess/Volume_0171.tgz Volume_0171
# job.batch/mapper172 created
# 173 gs://lpr-g1000-tess/Volume_0172.tgz Volume_0172
# job.batch/mapper173 created
# 174 gs://lpr-g1000-tess/Volume_0173.tgz Volume_0173
# job.batch/mapper174 created
# 175 gs://lpr-g1000-tess/Volume_0174.tgz Volume_0174
# job.batch/mapper175 created
# 176 gs://lpr-g1000-tess/Volume_0175.tgz Volume_0175
# job.batch/mapper176 created
# 177 gs://lpr-g1000-tess/Volume_0176.tgz Volume_0176
# job.batch/mapper177 created
# 178 gs://lpr-g1000-tess/Volume_0177.tgz Volume_0177
# job.batch/mapper178 created
# 179 gs://lpr-g1000-tess/Volume_0178.tgz Volume_0178
# job.batch/mapper179 created
# 180 gs://lpr-g1000-tess/Volume_0179.tgz Volume_0179
# job.batch/mapper180 created
# 181 gs://lpr-g1000-tess/Volume_0180.tgz Volume_0180
# job.batch/mapper181 created
# 182 gs://lpr-g1000-tess/Volume_0181.tgz Volume_0181
# job.batch/mapper182 created
# 183 gs://lpr-g1000-tess/Volume_0182.tgz Volume_0182
# job.batch/mapper183 created
# 184 gs://lpr-g1000-tess/Volume_0183.tgz Volume_0183
# job.batch/mapper184 created
# 185 gs://lpr-g1000-tess/Volume_0184.tgz Volume_0184
# job.batch/mapper185 created
# 186 gs://lpr-g1000-tess/Volume_0185.tgz Volume_0185
# job.batch/mapper186 created
# 187 gs://lpr-g1000-tess/Volume_0186.tgz Volume_0186
# job.batch/mapper187 created
# 188 gs://lpr-g1000-tess/Volume_0187.tgz Volume_0187
# job.batch/mapper188 created
# 189 gs://lpr-g1000-tess/Volume_0188.tgz Volume_0188
# job.batch/mapper189 created
# 190 gs://lpr-g1000-tess/Volume_0189.tgz Volume_0189
# job.batch/mapper190 created
# 191 gs://lpr-g1000-tess/Volume_0190.tgz Volume_0190
# job.batch/mapper191 created
# 192 gs://lpr-g1000-tess/Volume_0191.tgz Volume_0191
# job.batch/mapper192 created
# 193 gs://lpr-g1000-tess/Volume_0192.tgz Volume_0192
# job.batch/mapper193 created
# 194 gs://lpr-g1000-tess/Volume_0193.tgz Volume_0193
# job.batch/mapper194 created
# 195 gs://lpr-g1000-tess/Volume_0194.tgz Volume_0194
# job.batch/mapper195 created
# 196 gs://lpr-g1000-tess/Volume_0195.tgz Volume_0195
# job.batch/mapper196 created
# 197 gs://lpr-g1000-tess/Volume_0196.tgz Volume_0196
# job.batch/mapper197 created
# 198 gs://lpr-g1000-tess/Volume_0197.tgz Volume_0197
# job.batch/mapper198 created
# 199 gs://lpr-g1000-tess/Volume_0198.tgz Volume_0198
# job.batch/mapper199 created
# 200 gs://lpr-g1000-tess/Volume_0199.tgz Volume_0199
# job.batch/mapper200 created
# 201 gs://lpr-g1000-tess/Volume_0200.tgz Volume_0200
# job.batch/mapper201 created
# 202 gs://lpr-g1000-tess/Volume_0201.tgz Volume_0201
# job.batch/mapper202 created
# 203 gs://lpr-g1000-tess/Volume_0202.tgz Volume_0202
# job.batch/mapper203 created
# 204 gs://lpr-g1000-tess/Volume_0203.tgz Volume_0203
# job.batch/mapper204 created
# 205 gs://lpr-g1000-tess/Volume_0204.tgz Volume_0204
# job.batch/mapper205 created
# 206 gs://lpr-g1000-tess/Volume_0205.tgz Volume_0205
# job.batch/mapper206 created
# 207 gs://lpr-g1000-tess/Volume_0206.tgz Volume_0206
# job.batch/mapper207 created
# 208 gs://lpr-g1000-tess/Volume_0207.tgz Volume_0207
# job.batch/mapper208 created
# 209 gs://lpr-g1000-tess/Volume_0208.tgz Volume_0208
# job.batch/mapper209 created
# 210 gs://lpr-g1000-tess/Volume_0209.tgz Volume_0209
# job.batch/mapper210 created
# 211 gs://lpr-g1000-tess/Volume_0210.tgz Volume_0210
# job.batch/mapper211 created
# 212 gs://lpr-g1000-tess/Volume_0211.tgz Volume_0211
# job.batch/mapper212 created
# 213 gs://lpr-g1000-tess/Volume_0212.tgz Volume_0212
# job.batch/mapper213 created
# 214 gs://lpr-g1000-tess/Volume_0213.tgz Volume_0213
# job.batch/mapper214 created
# 215 gs://lpr-g1000-tess/Volume_0214.tgz Volume_0214
# job.batch/mapper215 created
# 216 gs://lpr-g1000-tess/Volume_0215.tgz Volume_0215
# job.batch/mapper216 created
# 217 gs://lpr-g1000-tess/Volume_0216.tgz Volume_0216
# job.batch/mapper217 created
# 218 gs://lpr-g1000-tess/Volume_0217.tgz Volume_0217
# job.batch/mapper218 created
# 219 gs://lpr-g1000-tess/Volume_0218.tgz Volume_0218
# job.batch/mapper219 created
# 220 gs://lpr-g1000-tess/Volume_0219.tgz Volume_0219
# job.batch/mapper220 created
# 221 gs://lpr-g1000-tess/Volume_0220.tgz Volume_0220
# job.batch/mapper221 created
# 222 gs://lpr-g1000-tess/Volume_0221.tgz Volume_0221
# job.batch/mapper222 created
# 223 gs://lpr-g1000-tess/Volume_0222.tgz Volume_0222
# job.batch/mapper223 created
# 224 gs://lpr-g1000-tess/Volume_0223.tgz Volume_0223
# job.batch/mapper224 created
# 225 gs://lpr-g1000-tess/Volume_0224.tgz Volume_0224
# job.batch/mapper225 created
# 226 gs://lpr-g1000-tess/Volume_0225.tgz Volume_0225
# job.batch/mapper226 created
# 227 gs://lpr-g1000-tess/Volume_0226.tgz Volume_0226
# job.batch/mapper227 created
# 228 gs://lpr-g1000-tess/Volume_0227.tgz Volume_0227
# job.batch/mapper228 created
# 229 gs://lpr-g1000-tess/Volume_0228.tgz Volume_0228
# job.batch/mapper229 created
# 230 gs://lpr-g1000-tess/Volume_0229.tgz Volume_0229
# job.batch/mapper230 created
# 231 gs://lpr-g1000-tess/Volume_0230.tgz Volume_0230
# job.batch/mapper231 created
# 232 gs://lpr-g1000-tess/Volume_0231.tgz Volume_0231
# job.batch/mapper232 created
# 233 gs://lpr-g1000-tess/Volume_0232.tgz Volume_0232
# job.batch/mapper233 created
# 234 gs://lpr-g1000-tess/Volume_0233.tgz Volume_0233
# job.batch/mapper234 created
# 235 gs://lpr-g1000-tess/Volume_0234.tgz Volume_0234
# job.batch/mapper235 created
# 236 gs://lpr-g1000-tess/Volume_0235.tgz Volume_0235
# job.batch/mapper236 created
# 237 gs://lpr-g1000-tess/Volume_0236.tgz Volume_0236
# job.batch/mapper237 created
# 238 gs://lpr-g1000-tess/Volume_0237.tgz Volume_0237
# job.batch/mapper238 created
# 239 gs://lpr-g1000-tess/Volume_0238.tgz Volume_0238
# job.batch/mapper239 created
# 240 gs://lpr-g1000-tess/Volume_0239.tgz Volume_0239
# job.batch/mapper240 created
# 241 gs://lpr-g1000-tess/Volume_0240.tgz Volume_0240
# job.batch/mapper241 created
# 242 gs://lpr-g1000-tess/Volume_0241.tgz Volume_0241
# job.batch/mapper242 created
# 243 gs://lpr-g1000-tess/Volume_0242.tgz Volume_0242
# job.batch/mapper243 created
# 244 gs://lpr-g1000-tess/Volume_0243.tgz Volume_0243
# job.batch/mapper244 created
# 245 gs://lpr-g1000-tess/Volume_0244.tgz Volume_0244
# job.batch/mapper245 created
# 246 gs://lpr-g1000-tess/Volume_0245.tgz Volume_0245
# job.batch/mapper246 created
# 247 gs://lpr-g1000-tess/Volume_0246.tgz Volume_0246
# job.batch/mapper247 created
# 248 gs://lpr-g1000-tess/Volume_0247.tgz Volume_0247
# job.batch/mapper248 created
# 249 gs://lpr-g1000-tess/Volume_0248.tgz Volume_0248
# job.batch/mapper249 created
# 250 gs://lpr-g1000-tess/Volume_0249.tgz Volume_0249
# job.batch/mapper250 created
# 251 gs://lpr-g1000-tess/Volume_0250.tgz Volume_0250
# job.batch/mapper251 created
# 252 gs://lpr-g1000-tess/Volume_0251.tgz Volume_0251
# job.batch/mapper252 created
# 253 gs://lpr-g1000-tess/Volume_0252.tgz Volume_0252
# job.batch/mapper253 created
# 254 gs://lpr-g1000-tess/Volume_0253.tgz Volume_0253
# job.batch/mapper254 created
# 255 gs://lpr-g1000-tess/Volume_0254.tgz Volume_0254
# job.batch/mapper255 created
# 256 gs://lpr-g1000-tess/Volume_0255.tgz Volume_0255
# job.batch/mapper256 created
# 257 gs://lpr-g1000-tess/Volume_0256.tgz Volume_0256
# job.batch/mapper257 created
# 258 gs://lpr-g1000-tess/Volume_0257.tgz Volume_0257
# job.batch/mapper258 created
# 259 gs://lpr-g1000-tess/Volume_0258.tgz Volume_0258
# job.batch/mapper259 created
# 260 gs://lpr-g1000-tess/Volume_0259.tgz Volume_0259
# job.batch/mapper260 created
# 261 gs://lpr-g1000-tess/Volume_0260.tgz Volume_0260
# job.batch/mapper261 created
# 262 gs://lpr-g1000-tess/Volume_0261.tgz Volume_0261
# job.batch/mapper262 created
# 263 gs://lpr-g1000-tess/Volume_0262.tgz Volume_0262
# job.batch/mapper263 created
# 264 gs://lpr-g1000-tess/Volume_0263.tgz Volume_0263
# job.batch/mapper264 created
# 265 gs://lpr-g1000-tess/Volume_0264.tgz Volume_0264
# job.batch/mapper265 created
# 266 gs://lpr-g1000-tess/Volume_0265.tgz Volume_0265
# job.batch/mapper266 created
# 267 gs://lpr-g1000-tess/Volume_0266.tgz Volume_0266
# job.batch/mapper267 created
# 268 gs://lpr-g1000-tess/Volume_0267.tgz Volume_0267
# job.batch/mapper268 created
# 269 gs://lpr-g1000-tess/Volume_0268.tgz Volume_0268
# job.batch/mapper269 created
# 270 gs://lpr-g1000-tess/Volume_0269.tgz Volume_0269
# job.batch/mapper270 created
# 271 gs://lpr-g1000-tess/Volume_0270.tgz Volume_0270
# job.batch/mapper271 created
# 272 gs://lpr-g1000-tess/Volume_0271.tgz Volume_0271
# job.batch/mapper272 created
# 273 gs://lpr-g1000-tess/Volume_0272.tgz Volume_0272
# job.batch/mapper273 created
# 274 gs://lpr-g1000-tess/Volume_0273.tgz Volume_0273
# job.batch/mapper274 created
# 275 gs://lpr-g1000-tess/Volume_0274.tgz Volume_0274
# job.batch/mapper275 created
# 276 gs://lpr-g1000-tess/Volume_0275.tgz Volume_0275
# job.batch/mapper276 created
# 277 gs://lpr-g1000-tess/Volume_0276.tgz Volume_0276
# job.batch/mapper277 created
# 278 gs://lpr-g1000-tess/Volume_0277.tgz Volume_0277
# job.batch/mapper278 created
# 279 gs://lpr-g1000-tess/Volume_0278.tgz Volume_0278
# job.batch/mapper279 created
# 280 gs://lpr-g1000-tess/Volume_0279.tgz Volume_0279
# job.batch/mapper280 created
# 281 gs://lpr-g1000-tess/Volume_0280.tgz Volume_0280
# job.batch/mapper281 created
# 282 gs://lpr-g1000-tess/Volume_0281.tgz Volume_0281
# job.batch/mapper282 created
# 283 gs://lpr-g1000-tess/Volume_0282.tgz Volume_0282
# job.batch/mapper283 created
# 284 gs://lpr-g1000-tess/Volume_0283.tgz Volume_0283
# job.batch/mapper284 created
# 285 gs://lpr-g1000-tess/Volume_0284.tgz Volume_0284
# job.batch/mapper285 created
# 286 gs://lpr-g1000-tess/Volume_0285.tgz Volume_0285
# job.batch/mapper286 created
# 287 gs://lpr-g1000-tess/Volume_0286.tgz Volume_0286
# job.batch/mapper287 created
# 288 gs://lpr-g1000-tess/Volume_0287.tgz Volume_0287
# job.batch/mapper288 created
# 289 gs://lpr-g1000-tess/Volume_0288.tgz Volume_0288
# job.batch/mapper289 created
# 290 gs://lpr-g1000-tess/Volume_0289.tgz Volume_0289
# job.batch/mapper290 created
# 291 gs://lpr-g1000-tess/Volume_0290.tgz Volume_0290
# job.batch/mapper291 created
# 292 gs://lpr-g1000-tess/Volume_0291.tgz Volume_0291
# job.batch/mapper292 created
# 293 gs://lpr-g1000-tess/Volume_0292.tgz Volume_0292
# job.batch/mapper293 created
# 294 gs://lpr-g1000-tess/Volume_0293.tgz Volume_0293
# job.batch/mapper294 created
# 295 gs://lpr-g1000-tess/Volume_0294.tgz Volume_0294
# job.batch/mapper295 created
# 296 gs://lpr-g1000-tess/Volume_0295.tgz Volume_0295
# job.batch/mapper296 created
# 297 gs://lpr-g1000-tess/Volume_0296.tgz Volume_0296
# job.batch/mapper297 created
# 298 gs://lpr-g1000-tess/Volume_0297.tgz Volume_0297
# job.batch/mapper298 created
# 299 gs://lpr-g1000-tess/Volume_0298.tgz Volume_0298
# job.batch/mapper299 created
# 300 gs://lpr-g1000-tess/Volume_0299.tgz Volume_0299
# job.batch/mapper300 created
# 301 gs://lpr-g1000-tess/Volume_0300.tgz Volume_0300
# job.batch/mapper301 created
# 302 gs://lpr-g1000-tess/Volume_0301.tgz Volume_0301
# job.batch/mapper302 created
# 303 gs://lpr-g1000-tess/Volume_0302.tgz Volume_0302
# job.batch/mapper303 created
# 304 gs://lpr-g1000-tess/Volume_0303.tgz Volume_0303
# job.batch/mapper304 created
# 305 gs://lpr-g1000-tess/Volume_0304.tgz Volume_0304
# job.batch/mapper305 created
# 306 gs://lpr-g1000-tess/Volume_0305.tgz Volume_0305
# job.batch/mapper306 created
# 307 gs://lpr-g1000-tess/Volume_0306.tgz Volume_0306
# job.batch/mapper307 created
# 308 gs://lpr-g1000-tess/Volume_0307.tgz Volume_0307
# job.batch/mapper308 created
# 309 gs://lpr-g1000-tess/Volume_0308.tgz Volume_0308
# job.batch/mapper309 created
# 310 gs://lpr-g1000-tess/Volume_0309.tgz Volume_0309
# job.batch/mapper310 created
# 311 gs://lpr-g1000-tess/Volume_0310.tgz Volume_0310
# job.batch/mapper311 created
# 312 gs://lpr-g1000-tess/Volume_0311.tgz Volume_0311
# job.batch/mapper312 created
# 313 gs://lpr-g1000-tess/Volume_0312.tgz Volume_0312
# job.batch/mapper313 created
# 314 gs://lpr-g1000-tess/Volume_0313.tgz Volume_0313
# job.batch/mapper314 created
# 315 gs://lpr-g1000-tess/Volume_0314.tgz Volume_0314
# job.batch/mapper315 created
# 316 gs://lpr-g1000-tess/Volume_0315.tgz Volume_0315
# job.batch/mapper316 created
# 317 gs://lpr-g1000-tess/Volume_0316.tgz Volume_0316
# job.batch/mapper317 created
# 318 gs://lpr-g1000-tess/Volume_0317.tgz Volume_0317
# job.batch/mapper318 created
# 319 gs://lpr-g1000-tess/Volume_0318.tgz Volume_0318
# job.batch/mapper319 created
# 320 gs://lpr-g1000-tess/Volume_0319.tgz Volume_0319
# job.batch/mapper320 created
# 321 gs://lpr-g1000-tess/Volume_0320.tgz Volume_0320
# job.batch/mapper321 created
# 322 gs://lpr-g1000-tess/Volume_0321.tgz Volume_0321
# job.batch/mapper322 created
# 323 gs://lpr-g1000-tess/Volume_0322.tgz Volume_0322
# job.batch/mapper323 created
# 324 gs://lpr-g1000-tess/Volume_0323.tgz Volume_0323
# job.batch/mapper324 created
# 325 gs://lpr-g1000-tess/Volume_0324.tgz Volume_0324
# job.batch/mapper325 created
# 326 gs://lpr-g1000-tess/Volume_0325.tgz Volume_0325
# job.batch/mapper326 created
# 327 gs://lpr-g1000-tess/Volume_0326.tgz Volume_0326
# job.batch/mapper327 created
# 328 gs://lpr-g1000-tess/Volume_0327.tgz Volume_0327
# job.batch/mapper328 created
# 329 gs://lpr-g1000-tess/Volume_0328.tgz Volume_0328
# job.batch/mapper329 created
# 330 gs://lpr-g1000-tess/Volume_0329.tgz Volume_0329
# job.batch/mapper330 created
# 331 gs://lpr-g1000-tess/Volume_0330.tgz Volume_0330
# job.batch/mapper331 created
# 332 gs://lpr-g1000-tess/Volume_0331.tgz Volume_0331
# job.batch/mapper332 created
# 333 gs://lpr-g1000-tess/Volume_0332.tgz Volume_0332
# job.batch/mapper333 created
# 334 gs://lpr-g1000-tess/Volume_0333.tgz Volume_0333
# job.batch/mapper334 created
# 335 gs://lpr-g1000-tess/Volume_0334.tgz Volume_0334
# job.batch/mapper335 created
# 336 gs://lpr-g1000-tess/Volume_0335.tgz Volume_0335
# job.batch/mapper336 created
# 337 gs://lpr-g1000-tess/Volume_0336.tgz Volume_0336
# job.batch/mapper337 created
# 338 gs://lpr-g1000-tess/Volume_0337.tgz Volume_0337
# job.batch/mapper338 created
# 339 gs://lpr-g1000-tess/Volume_0338.tgz Volume_0338
# job.batch/mapper339 created
# 340 gs://lpr-g1000-tess/Volume_0339.tgz Volume_0339
# job.batch/mapper340 created
# 341 gs://lpr-g1000-tess/Volume_0340.tgz Volume_0340
# job.batch/mapper341 created
# 342 gs://lpr-g1000-tess/Volume_0341.tgz Volume_0341
# job.batch/mapper342 created
# 343 gs://lpr-g1000-tess/Volume_0342.tgz Volume_0342
# job.batch/mapper343 created
# 344 gs://lpr-g1000-tess/Volume_0343.tgz Volume_0343
# job.batch/mapper344 created
# 345 gs://lpr-g1000-tess/Volume_0344.tgz Volume_0344
# job.batch/mapper345 created
# 346 gs://lpr-g1000-tess/Volume_0345.tgz Volume_0345
# job.batch/mapper346 created
# 347 gs://lpr-g1000-tess/Volume_0346.tgz Volume_0346
# job.batch/mapper347 created
# 348 gs://lpr-g1000-tess/Volume_0347.tgz Volume_0347
# job.batch/mapper348 created
# 349 gs://lpr-g1000-tess/Volume_0348.tgz Volume_0348
# job.batch/mapper349 created
# 350 gs://lpr-g1000-tess/Volume_0349.tgz Volume_0349
# job.batch/mapper350 created
# 351 gs://lpr-g1000-tess/Volume_0350.tgz Volume_0350
# job.batch/mapper351 created
# 352 gs://lpr-g1000-tess/Volume_0351.tgz Volume_0351
# job.batch/mapper352 created
# 353 gs://lpr-g1000-tess/Volume_0352.tgz Volume_0352
# job.batch/mapper353 created
# 354 gs://lpr-g1000-tess/Volume_0353.tgz Volume_0353
# job.batch/mapper354 created
# 355 gs://lpr-g1000-tess/Volume_0354.tgz Volume_0354
# job.batch/mapper355 created
# 356 gs://lpr-g1000-tess/Volume_0355.tgz Volume_0355
# job.batch/mapper356 created
# 357 gs://lpr-g1000-tess/Volume_0356.tgz Volume_0356
# job.batch/mapper357 created
# 358 gs://lpr-g1000-tess/Volume_0357.tgz Volume_0357
# job.batch/mapper358 created
# 359 gs://lpr-g1000-tess/Volume_0358.tgz Volume_0358
# job.batch/mapper359 created
# 360 gs://lpr-g1000-tess/Volume_0359.tgz Volume_0359
# job.batch/mapper360 created
# 361 gs://lpr-g1000-tess/Volume_0360.tgz Volume_0360
# job.batch/mapper361 created
# 362 gs://lpr-g1000-tess/Volume_0361.tgz Volume_0361
# job.batch/mapper362 created
# 363 gs://lpr-g1000-tess/Volume_0362.tgz Volume_0362
# job.batch/mapper363 created
# 364 gs://lpr-g1000-tess/Volume_0363.tgz Volume_0363
# job.batch/mapper364 created
# 365 gs://lpr-g1000-tess/Volume_0364.tgz Volume_0364
# job.batch/mapper365 created
# 366 gs://lpr-g1000-tess/Volume_0365.tgz Volume_0365
# job.batch/mapper366 created
# 367 gs://lpr-g1000-tess/Volume_0366.tgz Volume_0366
# job.batch/mapper367 created
# 368 gs://lpr-g1000-tess/Volume_0367.tgz Volume_0367
# job.batch/mapper368 created
# 369 gs://lpr-g1000-tess/Volume_0368.tgz Volume_0368
# job.batch/mapper369 created
# 370 gs://lpr-g1000-tess/Volume_0369.tgz Volume_0369
# job.batch/mapper370 created
# 371 gs://lpr-g1000-tess/Volume_0370.tgz Volume_0370
# job.batch/mapper371 created
# 372 gs://lpr-g1000-tess/Volume_0371.tgz Volume_0371
# job.batch/mapper372 created
# 373 gs://lpr-g1000-tess/Volume_0372.tgz Volume_0372
# job.batch/mapper373 created
# 374 gs://lpr-g1000-tess/Volume_0373.tgz Volume_0373
# job.batch/mapper374 created
# 375 gs://lpr-g1000-tess/Volume_0374.tgz Volume_0374
# job.batch/mapper375 created
# 376 gs://lpr-g1000-tess/Volume_0375.tgz Volume_0375
# job.batch/mapper376 created
# 377 gs://lpr-g1000-tess/Volume_0376.tgz Volume_0376
# job.batch/mapper377 created
# 378 gs://lpr-g1000-tess/Volume_0377.tgz Volume_0377
# job.batch/mapper378 created
# 379 gs://lpr-g1000-tess/Volume_0378.tgz Volume_0378
# job.batch/mapper379 created
# 380 gs://lpr-g1000-tess/Volume_0379.tgz Volume_0379
# job.batch/mapper380 created
# 381 gs://lpr-g1000-tess/Volume_0380.tgz Volume_0380
# job.batch/mapper381 created
# 382 gs://lpr-g1000-tess/Volume_0381.tgz Volume_0381
# job.batch/mapper382 created
# 383 gs://lpr-g1000-tess/Volume_0382.tgz Volume_0382
# job.batch/mapper383 created
# 384 gs://lpr-g1000-tess/Volume_0383.tgz Volume_0383
# job.batch/mapper384 created
# 385 gs://lpr-g1000-tess/Volume_0384.tgz Volume_0384
# job.batch/mapper385 created
# 386 gs://lpr-g1000-tess/Volume_0385.tgz Volume_0385
# job.batch/mapper386 created
# 387 gs://lpr-g1000-tess/Volume_0386.tgz Volume_0386
# job.batch/mapper387 created
# 388 gs://lpr-g1000-tess/Volume_0387.tgz Volume_0387
# job.batch/mapper388 created
# 389 gs://lpr-g1000-tess/Volume_0388.tgz Volume_0388
# job.batch/mapper389 created
# 390 gs://lpr-g1000-tess/Volume_0389.tgz Volume_0389
# job.batch/mapper390 created
# 391 gs://lpr-g1000-tess/Volume_0390.tgz Volume_0390
# job.batch/mapper391 created
# 392 gs://lpr-g1000-tess/Volume_0391.tgz Volume_0391
# job.batch/mapper392 created
# 393 gs://lpr-g1000-tess/Volume_0392.tgz Volume_0392
# job.batch/mapper393 created
# 394 gs://lpr-g1000-tess/Volume_0393.tgz Volume_0393
# job.batch/mapper394 created
# 395 gs://lpr-g1000-tess/Volume_0394.tgz Volume_0394
# job.batch/mapper395 created
# 396 gs://lpr-g1000-tess/Volume_0395.tgz Volume_0395
# job.batch/mapper396 created
# 397 gs://lpr-g1000-tess/Volume_0396.tgz Volume_0396
# job.batch/mapper397 created
# 398 gs://lpr-g1000-tess/Volume_0397.tgz Volume_0397
# job.batch/mapper398 created
# 399 gs://lpr-g1000-tess/Volume_0398.tgz Volume_0398
# job.batch/mapper399 created
# 400 gs://lpr-g1000-tess/Volume_0399.tgz Volume_0399
# job.batch/mapper400 created
# 401 gs://lpr-g1000-tess/Volume_0400.tgz Volume_0400
# job.batch/mapper401 created
# 402 gs://lpr-g1000-tess/Volume_0401.tgz Volume_0401
# job.batch/mapper402 created
# 403 gs://lpr-g1000-tess/Volume_0402.tgz Volume_0402
# job.batch/mapper403 created
# 404 gs://lpr-g1000-tess/Volume_0403.tgz Volume_0403
# job.batch/mapper404 created
# 405 gs://lpr-g1000-tess/Volume_0404.tgz Volume_0404
# job.batch/mapper405 created
# 406 gs://lpr-g1000-tess/Volume_0405.tgz Volume_0405
# job.batch/mapper406 created
# 407 gs://lpr-g1000-tess/Volume_0406.tgz Volume_0406
# job.batch/mapper407 created
# 408 gs://lpr-g1000-tess/Volume_0407.tgz Volume_0407
# job.batch/mapper408 created
# 409 gs://lpr-g1000-tess/Volume_0408.tgz Volume_0408
# job.batch/mapper409 created
# 410 gs://lpr-g1000-tess/Volume_0409.tgz Volume_0409
# job.batch/mapper410 created
# 411 gs://lpr-g1000-tess/Volume_0410.tgz Volume_0410
# job.batch/mapper411 created
# 412 gs://lpr-g1000-tess/Volume_0411.tgz Volume_0411
# job.batch/mapper412 created
# 413 gs://lpr-g1000-tess/Volume_0412.tgz Volume_0412
# job.batch/mapper413 created
# 414 gs://lpr-g1000-tess/Volume_0413.tgz Volume_0413
# job.batch/mapper414 created
# 415 gs://lpr-g1000-tess/Volume_0414.tgz Volume_0414
# job.batch/mapper415 created
# 416 gs://lpr-g1000-tess/Volume_0415.tgz Volume_0415
# job.batch/mapper416 created
# 417 gs://lpr-g1000-tess/Volume_0416.tgz Volume_0416
# job.batch/mapper417 created
# 418 gs://lpr-g1000-tess/Volume_0417.tgz Volume_0417
# job.batch/mapper418 created
# 419 gs://lpr-g1000-tess/Volume_0418.tgz Volume_0418
# job.batch/mapper419 created
# 420 gs://lpr-g1000-tess/Volume_0419.tgz Volume_0419
# job.batch/mapper420 created
# 421 gs://lpr-g1000-tess/Volume_0420.tgz Volume_0420
# job.batch/mapper421 created
# 422 gs://lpr-g1000-tess/Volume_0421.tgz Volume_0421
# job.batch/mapper422 created
# 423 gs://lpr-g1000-tess/Volume_0422.tgz Volume_0422
# job.batch/mapper423 created
# 424 gs://lpr-g1000-tess/Volume_0423.tgz Volume_0423
# job.batch/mapper424 created
# 425 gs://lpr-g1000-tess/Volume_0424.tgz Volume_0424
# job.batch/mapper425 created
# 426 gs://lpr-g1000-tess/Volume_0425.tgz Volume_0425
# job.batch/mapper426 created
# 427 gs://lpr-g1000-tess/Volume_0426.tgz Volume_0426
# job.batch/mapper427 created
# 428 gs://lpr-g1000-tess/Volume_0427.tgz Volume_0427
# job.batch/mapper428 created
# 429 gs://lpr-g1000-tess/Volume_0428.tgz Volume_0428
# job.batch/mapper429 created
# 430 gs://lpr-g1000-tess/Volume_0429.tgz Volume_0429
# job.batch/mapper430 created
# 431 gs://lpr-g1000-tess/Volume_0430.tgz Volume_0430
# job.batch/mapper431 created
# 432 gs://lpr-g1000-tess/Volume_0431.tgz Volume_0431
# job.batch/mapper432 created
# 433 gs://lpr-g1000-tess/Volume_0432.tgz Volume_0432
# job.batch/mapper433 created
# 434 gs://lpr-g1000-tess/Volume_0433.tgz Volume_0433
# job.batch/mapper434 created
# 435 gs://lpr-g1000-tess/Volume_0434.tgz Volume_0434
# job.batch/mapper435 created
# 436 gs://lpr-g1000-tess/Volume_0435.tgz Volume_0435
# job.batch/mapper436 created
# 437 gs://lpr-g1000-tess/Volume_0436.tgz Volume_0436
# job.batch/mapper437 created
# 438 gs://lpr-g1000-tess/Volume_0437.tgz Volume_0437
# job.batch/mapper438 created
# 439 gs://lpr-g1000-tess/Volume_0438.tgz Volume_0438
# job.batch/mapper439 created
# 440 gs://lpr-g1000-tess/Volume_0439.tgz Volume_0439
# job.batch/mapper440 created
# 441 gs://lpr-g1000-tess/Volume_0440.tgz Volume_0440
# job.batch/mapper441 created
# 442 gs://lpr-g1000-tess/Volume_0441.tgz Volume_0441
# job.batch/mapper442 created
# 443 gs://lpr-g1000-tess/Volume_0442.tgz Volume_0442
# job.batch/mapper443 created
# 444 gs://lpr-g1000-tess/Volume_0443.tgz Volume_0443
# job.batch/mapper444 created
# 445 gs://lpr-g1000-tess/Volume_0444.tgz Volume_0444
# job.batch/mapper445 created
# 446 gs://lpr-g1000-tess/Volume_0445.tgz Volume_0445
# job.batch/mapper446 created
# 447 gs://lpr-g1000-tess/Volume_0446.tgz Volume_0446
# job.batch/mapper447 created
# 448 gs://lpr-g1000-tess/Volume_0447.tgz Volume_0447
# job.batch/mapper448 created
# 449 gs://lpr-g1000-tess/Volume_0448.tgz Volume_0448
# job.batch/mapper449 created
# 450 gs://lpr-g1000-tess/Volume_0449.tgz Volume_0449
# job.batch/mapper450 created
# 451 gs://lpr-g1000-tess/Volume_0450.tgz Volume_0450
# job.batch/mapper451 created
# 452 gs://lpr-g1000-tess/Volume_0451.tgz Volume_0451
# job.batch/mapper452 created
# 453 gs://lpr-g1000-tess/Volume_0452.tgz Volume_0452
# job.batch/mapper453 created
# 454 gs://lpr-g1000-tess/Volume_0453.tgz Volume_0453
# job.batch/mapper454 created
# 455 gs://lpr-g1000-tess/Volume_0454.tgz Volume_0454
# job.batch/mapper455 created
# 456 gs://lpr-g1000-tess/Volume_0455.tgz Volume_0455
# job.batch/mapper456 created
# 457 gs://lpr-g1000-tess/Volume_0456.tgz Volume_0456
# job.batch/mapper457 created
# 458 gs://lpr-g1000-tess/Volume_0457.tgz Volume_0457
# job.batch/mapper458 created
# 459 gs://lpr-g1000-tess/Volume_0458.tgz Volume_0458
# job.batch/mapper459 created
# 460 gs://lpr-g1000-tess/Volume_0459.tgz Volume_0459
# job.batch/mapper460 created
# 461 gs://lpr-g1000-tess/Volume_0460.tgz Volume_0460
# job.batch/mapper461 created
# 462 gs://lpr-g1000-tess/Volume_0461.tgz Volume_0461
# job.batch/mapper462 created
# 463 gs://lpr-g1000-tess/Volume_0462.tgz Volume_0462
# job.batch/mapper463 created
# 464 gs://lpr-g1000-tess/Volume_0463.tgz Volume_0463
# job.batch/mapper464 created
# 465 gs://lpr-g1000-tess/Volume_0464.tgz Volume_0464
# job.batch/mapper465 created
# 466 gs://lpr-g1000-tess/Volume_0465.tgz Volume_0465
# job.batch/mapper466 created
# 467 gs://lpr-g1000-tess/Volume_0466.tgz Volume_0466
# job.batch/mapper467 created
# 468 gs://lpr-g1000-tess/Volume_0467.tgz Volume_0467
# job.batch/mapper468 created
# 469 gs://lpr-g1000-tess/Volume_0468.tgz Volume_0468
# job.batch/mapper469 created
# 470 gs://lpr-g1000-tess/Volume_0469.tgz Volume_0469
# job.batch/mapper470 created
# 471 gs://lpr-g1000-tess/Volume_0470.tgz Volume_0470
# job.batch/mapper471 created
# 472 gs://lpr-g1000-tess/Volume_0471.tgz Volume_0471
# job.batch/mapper472 created
# 473 gs://lpr-g1000-tess/Volume_0472.tgz Volume_0472
# job.batch/mapper473 created
# 474 gs://lpr-g1000-tess/Volume_0473.tgz Volume_0473
# job.batch/mapper474 created
# 475 gs://lpr-g1000-tess/Volume_0474.tgz Volume_0474
# job.batch/mapper475 created
# 476 gs://lpr-g1000-tess/Volume_0475.tgz Volume_0475
# job.batch/mapper476 created
# 477 gs://lpr-g1000-tess/Volume_0476.tgz Volume_0476
# job.batch/mapper477 created
# 478 gs://lpr-g1000-tess/Volume_0477.tgz Volume_0477
# job.batch/mapper478 created
# 479 gs://lpr-g1000-tess/Volume_0478.tgz Volume_0478
# job.batch/mapper479 created
# 480 gs://lpr-g1000-tess/Volume_0479.tgz Volume_0479
# job.batch/mapper480 created
# 481 gs://lpr-g1000-tess/Volume_0480.tgz Volume_0480
# job.batch/mapper481 created
# 482 gs://lpr-g1000-tess/Volume_0481.tgz Volume_0481
# job.batch/mapper482 created
# 483 gs://lpr-g1000-tess/Volume_0482.tgz Volume_0482
# job.batch/mapper483 created
# 484 gs://lpr-g1000-tess/Volume_0483.tgz Volume_0483
# job.batch/mapper484 created
# 485 gs://lpr-g1000-tess/Volume_0484.tgz Volume_0484
# job.batch/mapper485 created
# 486 gs://lpr-g1000-tess/Volume_0485.tgz Volume_0485
# job.batch/mapper486 created
# 487 gs://lpr-g1000-tess/Volume_0486.tgz Volume_0486
# job.batch/mapper487 created
# 488 gs://lpr-g1000-tess/Volume_0487.tgz Volume_0487
# job.batch/mapper488 created
# 489 gs://lpr-g1000-tess/Volume_0488.tgz Volume_0488
# job.batch/mapper489 created
# 490 gs://lpr-g1000-tess/Volume_0489.tgz Volume_0489
# job.batch/mapper490 created
# 491 gs://lpr-g1000-tess/Volume_0490.tgz Volume_0490
# job.batch/mapper491 created
# 492 gs://lpr-g1000-tess/Volume_0491.tgz Volume_0491
# job.batch/mapper492 created
# 493 gs://lpr-g1000-tess/Volume_0492.tgz Volume_0492
# job.batch/mapper493 created
# 494 gs://lpr-g1000-tess/Volume_0493.tgz Volume_0493
# job.batch/mapper494 created
# 495 gs://lpr-g1000-tess/Volume_0494.tgz Volume_0494
# job.batch/mapper495 created
# 496 gs://lpr-g1000-tess/Volume_0495.tgz Volume_0495
# job.batch/mapper496 created
# 497 gs://lpr-g1000-tess/Volume_0496.tgz Volume_0496
# job.batch/mapper497 created
# 498 gs://lpr-g1000-tess/Volume_0497.tgz Volume_0497
# job.batch/mapper498 created
# 499 gs://lpr-g1000-tess/Volume_0498.tgz Volume_0498
# job.batch/mapper499 created
# 500 gs://lpr-g1000-tess/Volume_0499.tgz Volume_0499
# job.batch/mapper500 created
# 501 gs://lpr-g1000-tess/Volume_0500.tgz Volume_0500
# job.batch/mapper501 created
# 502 gs://lpr-g1000-tess/Volume_0501.tgz Volume_0501
# job.batch/mapper502 created
# 503 gs://lpr-g1000-tess/Volume_0502.tgz Volume_0502
# job.batch/mapper503 created
# 504 gs://lpr-g1000-tess/Volume_0503.tgz Volume_0503
# job.batch/mapper504 created
# 505 gs://lpr-g1000-tess/Volume_0504.tgz Volume_0504
# job.batch/mapper505 created
# 506 gs://lpr-g1000-tess/Volume_0505.tgz Volume_0505
# job.batch/mapper506 created
# 507 gs://lpr-g1000-tess/Volume_0506.tgz Volume_0506
# job.batch/mapper507 created
# 508 gs://lpr-g1000-tess/Volume_0507.tgz Volume_0507
# job.batch/mapper508 created
# 509 gs://lpr-g1000-tess/Volume_0508.tgz Volume_0508
# job.batch/mapper509 created
# 510 gs://lpr-g1000-tess/Volume_0509.tgz Volume_0509
# job.batch/mapper510 created
# 511 gs://lpr-g1000-tess/Volume_0510.tgz Volume_0510
# job.batch/mapper511 created
# 512 gs://lpr-g1000-tess/Volume_0511.tgz Volume_0511
# job.batch/mapper512 created
# 513 gs://lpr-g1000-tess/Volume_0512.tgz Volume_0512
# job.batch/mapper513 created
# 514 gs://lpr-g1000-tess/Volume_0513.tgz Volume_0513
# job.batch/mapper514 created
# 515 gs://lpr-g1000-tess/Volume_0514.tgz Volume_0514
# job.batch/mapper515 created
# 516 gs://lpr-g1000-tess/Volume_0515.tgz Volume_0515
# job.batch/mapper516 created
# 517 gs://lpr-g1000-tess/Volume_0516.tgz Volume_0516
# job.batch/mapper517 created
# 518 gs://lpr-g1000-tess/Volume_0517.tgz Volume_0517
# job.batch/mapper518 created
# 519 gs://lpr-g1000-tess/Volume_0518.tgz Volume_0518
# job.batch/mapper519 created
# 520 gs://lpr-g1000-tess/Volume_0519.tgz Volume_0519
# job.batch/mapper520 created
# 521 gs://lpr-g1000-tess/Volume_0520.tgz Volume_0520
# job.batch/mapper521 created
# 522 gs://lpr-g1000-tess/Volume_0521.tgz Volume_0521
# job.batch/mapper522 created
# 523 gs://lpr-g1000-tess/Volume_0522.tgz Volume_0522
# job.batch/mapper523 created
# 524 gs://lpr-g1000-tess/Volume_0523.tgz Volume_0523
# job.batch/mapper524 created
# 525 gs://lpr-g1000-tess/Volume_0524.tgz Volume_0524
# job.batch/mapper525 created
# 526 gs://lpr-g1000-tess/Volume_0525.tgz Volume_0525
# job.batch/mapper526 created
# 527 gs://lpr-g1000-tess/Volume_0526.tgz Volume_0526
# job.batch/mapper527 created
# 528 gs://lpr-g1000-tess/Volume_0527.tgz Volume_0527
# job.batch/mapper528 created
# 529 gs://lpr-g1000-tess/Volume_0528.tgz Volume_0528
# job.batch/mapper529 created
# 530 gs://lpr-g1000-tess/Volume_0529.tgz Volume_0529
# job.batch/mapper530 created
# 531 gs://lpr-g1000-tess/Volume_0530.tgz Volume_0530
# job.batch/mapper531 created
# 532 gs://lpr-g1000-tess/Volume_0531.tgz Volume_0531
# job.batch/mapper532 created
# 533 gs://lpr-g1000-tess/Volume_0532.tgz Volume_0532
# job.batch/mapper533 created
# 534 gs://lpr-g1000-tess/Volume_0533.tgz Volume_0533
# job.batch/mapper534 created
# 535 gs://lpr-g1000-tess/Volume_0534.tgz Volume_0534
# job.batch/mapper535 created
# 536 gs://lpr-g1000-tess/Volume_0535.tgz Volume_0535
# job.batch/mapper536 created
# 537 gs://lpr-g1000-tess/Volume_0536.tgz Volume_0536
# job.batch/mapper537 created
# 538 gs://lpr-g1000-tess/Volume_0537.tgz Volume_0537
# job.batch/mapper538 created
# 539 gs://lpr-g1000-tess/Volume_0538.tgz Volume_0538
# job.batch/mapper539 created
# 540 gs://lpr-g1000-tess/Volume_0539.tgz Volume_0539
# job.batch/mapper540 created
# 541 gs://lpr-g1000-tess/Volume_0540.tgz Volume_0540
# job.batch/mapper541 created
# 542 gs://lpr-g1000-tess/Volume_0541.tgz Volume_0541
# job.batch/mapper542 created
# 543 gs://lpr-g1000-tess/Volume_0542.tgz Volume_0542
# job.batch/mapper543 created
# 544 gs://lpr-g1000-tess/Volume_0543.tgz Volume_0543
# job.batch/mapper544 created
# 545 gs://lpr-g1000-tess/Volume_0544.tgz Volume_0544
# job.batch/mapper545 created
# 546 gs://lpr-g1000-tess/Volume_0545.tgz Volume_0545
# job.batch/mapper546 created
# 547 gs://lpr-g1000-tess/Volume_0546.tgz Volume_0546
# job.batch/mapper547 created
# 548 gs://lpr-g1000-tess/Volume_0547.tgz Volume_0547
# job.batch/mapper548 created
# 549 gs://lpr-g1000-tess/Volume_0548.tgz Volume_0548
# job.batch/mapper549 created
# 550 gs://lpr-g1000-tess/Volume_0549.tgz Volume_0549
# job.batch/mapper550 created
# 551 gs://lpr-g1000-tess/Volume_0550.tgz Volume_0550
# job.batch/mapper551 created
# 552 gs://lpr-g1000-tess/Volume_0551.tgz Volume_0551
# job.batch/mapper552 created
# 553 gs://lpr-g1000-tess/Volume_0552.tgz Volume_0552
# job.batch/mapper553 created
# 554 gs://lpr-g1000-tess/Volume_0553.tgz Volume_0553
# job.batch/mapper554 created
# 555 gs://lpr-g1000-tess/Volume_0554.tgz Volume_0554
# job.batch/mapper555 created
# 556 gs://lpr-g1000-tess/Volume_0555.tgz Volume_0555
# job.batch/mapper556 created
# 557 gs://lpr-g1000-tess/Volume_0556.tgz Volume_0556
# job.batch/mapper557 created
# 558 gs://lpr-g1000-tess/Volume_0557.tgz Volume_0557
# job.batch/mapper558 created
# 559 gs://lpr-g1000-tess/Volume_0558.tgz Volume_0558
# job.batch/mapper559 created
# 560 gs://lpr-g1000-tess/Volume_0559.tgz Volume_0559
# job.batch/mapper560 created
# 561 gs://lpr-g1000-tess/Volume_0560.tgz Volume_0560
# job.batch/mapper561 created
# 562 gs://lpr-g1000-tess/Volume_0561.tgz Volume_0561
# job.batch/mapper562 created
# 563 gs://lpr-g1000-tess/Volume_0562.tgz Volume_0562
# job.batch/mapper563 created
# 564 gs://lpr-g1000-tess/Volume_0563.tgz Volume_0563
# job.batch/mapper564 created
# 565 gs://lpr-g1000-tess/Volume_0564.tgz Volume_0564
# job.batch/mapper565 created
# 566 gs://lpr-g1000-tess/Volume_0565.tgz Volume_0565
# job.batch/mapper566 created
# 567 gs://lpr-g1000-tess/Volume_0566.tgz Volume_0566
# job.batch/mapper567 created
# 568 gs://lpr-g1000-tess/Volume_0567.tgz Volume_0567
# job.batch/mapper568 created
# 569 gs://lpr-g1000-tess/Volume_0568.tgz Volume_0568
# job.batch/mapper569 created
# 570 gs://lpr-g1000-tess/Volume_0569.tgz Volume_0569
# job.batch/mapper570 created
# 571 gs://lpr-g1000-tess/Volume_0570.tgz Volume_0570
# job.batch/mapper571 created
# 572 gs://lpr-g1000-tess/Volume_0571.tgz Volume_0571
# job.batch/mapper572 created
# 573 gs://lpr-g1000-tess/Volume_0572.tgz Volume_0572
# job.batch/mapper573 created
# 574 gs://lpr-g1000-tess/Volume_0573.tgz Volume_0573
# job.batch/mapper574 created
# 575 gs://lpr-g1000-tess/Volume_0574.tgz Volume_0574
# job.batch/mapper575 created
# 576 gs://lpr-g1000-tess/Volume_0575.tgz Volume_0575
# job.batch/mapper576 created
# 577 gs://lpr-g1000-tess/Volume_0576.tgz Volume_0576
# job.batch/mapper577 created
# 578 gs://lpr-g1000-tess/Volume_0577.tgz Volume_0577
# job.batch/mapper578 created
# 579 gs://lpr-g1000-tess/Volume_0578.tgz Volume_0578
# job.batch/mapper579 created
# 580 gs://lpr-g1000-tess/Volume_0579.tgz Volume_0579
# job.batch/mapper580 created
# 581 gs://lpr-g1000-tess/Volume_0580.tgz Volume_0580
# job.batch/mapper581 created
# 582 gs://lpr-g1000-tess/Volume_0581.tgz Volume_0581
# job.batch/mapper582 created
# 583 gs://lpr-g1000-tess/Volume_0582.tgz Volume_0582
# job.batch/mapper583 created
# 584 gs://lpr-g1000-tess/Volume_0583.tgz Volume_0583
# job.batch/mapper584 created
# 585 gs://lpr-g1000-tess/Volume_0584.tgz Volume_0584
# job.batch/mapper585 created
# 586 gs://lpr-g1000-tess/Volume_0585.tgz Volume_0585
# job.batch/mapper586 created
# 587 gs://lpr-g1000-tess/Volume_0586.tgz Volume_0586
# job.batch/mapper587 created
# 588 gs://lpr-g1000-tess/Volume_0587.tgz Volume_0587
# job.batch/mapper588 created
# 589 gs://lpr-g1000-tess/Volume_0588.tgz Volume_0588
# job.batch/mapper589 created
# 590 gs://lpr-g1000-tess/Volume_0589.tgz Volume_0589
# job.batch/mapper590 created
# 591 gs://lpr-g1000-tess/Volume_0590.tgz Volume_0590
# job.batch/mapper591 created
# 592 gs://lpr-g1000-tess/Volume_0591.tgz Volume_0591
# job.batch/mapper592 created
# 593 gs://lpr-g1000-tess/Volume_0592.tgz Volume_0592
# job.batch/mapper593 created
# 594 gs://lpr-g1000-tess/Volume_0593.tgz Volume_0593
# job.batch/mapper594 created
# 595 gs://lpr-g1000-tess/Volume_0594.tgz Volume_0594
# job.batch/mapper595 created
# 596 gs://lpr-g1000-tess/Volume_0595.tgz Volume_0595
# job.batch/mapper596 created
# 597 gs://lpr-g1000-tess/Volume_0596.tgz Volume_0596
# job.batch/mapper597 created
# 598 gs://lpr-g1000-tess/Volume_0597.tgz Volume_0597
# job.batch/mapper598 created
# 599 gs://lpr-g1000-tess/Volume_0598.tgz Volume_0598
# job.batch/mapper599 created
# 600 gs://lpr-g1000-tess/Volume_0599.tgz Volume_0599
# job.batch/mapper600 created
# 601 gs://lpr-g1000-tess/Volume_0600.tgz Volume_0600
# job.batch/mapper601 created
# 602 gs://lpr-g1000-tess/Volume_0601.tgz Volume_0601
# job.batch/mapper602 created
# 603 gs://lpr-g1000-tess/Volume_0602.tgz Volume_0602
# ...
# job.batch/mapper801 created
# 802 gs://lpr-g1000-tess/Volume_0801.tgz Volume_0801
# job.batch/mapper802 created
# 803 gs://lpr-g1000-tess/Volume_0802.tgz Volume_0802
# job.batch/mapper803 created
# 804 gs://lpr-g1000-tess/Volume_0803.tgz Volume_0803
# job.batch/mapper804 created
# 805 gs://lpr-g1000-tess/Volume_0804.tgz Volume_0804
# job.batch/mapper805 created
# 806 gs://lpr-g1000-tess/Volume_0805.tgz Volume_0805
# job.batch/mapper806 created
# 807 gs://lpr-g1000-tess/Volume_0806.tgz Volume_0806
# job.batch/mapper807 created
# 808 gs://lpr-g1000-tess/Volume_0807.tgz Volume_0807
# job.batch/mapper808 created
# 809 gs://lpr-g1000-tess/Volume_0808.tgz Volume_0808
# job.batch/mapper809 created
# 810 gs://lpr-g1000-tess/Volume_0809.tgz Volume_0809
# job.batch/mapper810 created
# 811 gs://lpr-g1000-tess/Volume_0810.tgz Volume_0810
# job.batch/mapper811 created
# 812 gs://lpr-g1000-tess/Volume_0811.tgz Volume_0811
# job.batch/mapper812 created
# 813 gs://lpr-g1000-tess/Volume_0812.tgz Volume_0812
# job.batch/mapper813 created
# 814 gs://lpr-g1000-tess/Volume_0813.tgz Volume_0813
# job.batch/mapper814 created
# 815 gs://lpr-g1000-tess/Volume_0814.tgz Volume_0814
# job.batch/mapper815 created
# 816 gs://lpr-g1000-tess/Volume_0815.tgz Volume_0815
# job.batch/mapper816 created
# 817 gs://lpr-g1000-tess/Volume_0816.tgz Volume_0816
# job.batch/mapper817 created
# 818 gs://lpr-g1000-tess/Volume_0817.tgz Volume_0817
# job.batch/mapper818 created
# 819 gs://lpr-g1000-tess/Volume_0818.tgz Volume_0818
# job.batch/mapper819 created
# 820 gs://lpr-g1000-tess/Volume_0819.tgz Volume_0819
# job.batch/mapper820 created
# 821 gs://lpr-g1000-tess/Volume_0820.tgz Volume_0820
# job.batch/mapper821 created
# 822 gs://lpr-g1000-tess/Volume_0821.tgz Volume_0821
# job.batch/mapper822 created
# 823 gs://lpr-g1000-tess/Volume_0822.tgz Volume_0822
# job.batch/mapper823 created
# 824 gs://lpr-g1000-tess/Volume_0823.tgz Volume_0823
# job.batch/mapper824 created
# 825 gs://lpr-g1000-tess/Volume_0824.tgz Volume_0824
# job.batch/mapper825 created
# 826 gs://lpr-g1000-tess/Volume_0825.tgz Volume_0825
# job.batch/mapper826 created
# 827 gs://lpr-g1000-tess/Volume_0826.tgz Volume_0826
# job.batch/mapper827 created
# 828 gs://lpr-g1000-tess/Volume_0827.tgz Volume_0827
# job.batch/mapper828 created
# 829 gs://lpr-g1000-tess/Volume_0828.tgz Volume_0828
# job.batch/mapper829 created
# 830 gs://lpr-g1000-tess/Volume_0829.tgz Volume_0829
# job.batch/mapper830 created
# 831 gs://lpr-g1000-tess/Volume_0830.tgz Volume_0830
# job.batch/mapper831 created
# 832 gs://lpr-g1000-tess/Volume_0831.tgz Volume_0831
# job.batch/mapper832 created
# 833 gs://lpr-g1000-tess/Volume_0832.tgz Volume_0832
# job.batch/mapper833 created
# 834 gs://lpr-g1000-tess/Volume_0833.tgz Volume_0833
# job.batch/mapper834 created
# 835 gs://lpr-g1000-tess/Volume_0834.tgz Volume_0834
# job.batch/mapper835 created
# 836 gs://lpr-g1000-tess/Volume_0835.tgz Volume_0835
# job.batch/mapper836 created
# 837 gs://lpr-g1000-tess/Volume_0836.tgz Volume_0836
# job.batch/mapper837 created
# 838 gs://lpr-g1000-tess/Volume_0837.tgz Volume_0837
# job.batch/mapper838 created
# 839 gs://lpr-g1000-tess/Volume_0838.tgz Volume_0838
# job.batch/mapper839 created
# 840 gs://lpr-g1000-tess/Volume_0839.tgz Volume_0839
# job.batch/mapper840 created
# 841 gs://lpr-g1000-tess/Volume_0840.tgz Volume_0840
# job.batch/mapper841 created
# 842 gs://lpr-g1000-tess/Volume_0841.tgz Volume_0841
# job.batch/mapper842 created
# 843 gs://lpr-g1000-tess/Volume_0842.tgz Volume_0842
# job.batch/mapper843 created
# 844 gs://lpr-g1000-tess/Volume_0843.tgz Volume_0843
# job.batch/mapper844 created
# 845 gs://lpr-g1000-tess/Volume_0844.tgz Volume_0844
# job.batch/mapper845 created
# 846 gs://lpr-g1000-tess/Volume_0845.tgz Volume_0845
# job.batch/mapper846 created
# 847 gs://lpr-g1000-tess/Volume_0846.tgz Volume_0846
# job.batch/mapper847 created
# 848 gs://lpr-g1000-tess/Volume_0847.tgz Volume_0847
# job.batch/mapper848 created
# 849 gs://lpr-g1000-tess/Volume_0848.tgz Volume_0848
# job.batch/mapper849 created
# 850 gs://lpr-g1000-tess/Volume_0849.tgz Volume_0849
# job.batch/mapper850 created
# 851 gs://lpr-g1000-tess/Volume_0850.tgz Volume_0850
# job.batch/mapper851 created
# 852 gs://lpr-g1000-tess/Volume_0851.tgz Volume_0851
# job.batch/mapper852 created
# 853 gs://lpr-g1000-tess/Volume_0852.tgz Volume_0852
# job.batch/mapper853 created
# 854 gs://lpr-g1000-tess/Volume_0853.tgz Volume_0853
# job.batch/mapper854 created
# 855 gs://lpr-g1000-tess/Volume_0854.tgz Volume_0854
# job.batch/mapper855 created
# 856 gs://lpr-g1000-tess/Volume_0855.tgz Volume_0855
# job.batch/mapper856 created
# 857 gs://lpr-g1000-tess/Volume_0856.tgz Volume_0856
# job.batch/mapper857 created
# 858 gs://lpr-g1000-tess/Volume_0857.tgz Volume_0857
# job.batch/mapper858 created
# 859 gs://lpr-g1000-tess/Volume_0858.tgz Volume_0858
# job.batch/mapper859 created
# 860 gs://lpr-g1000-tess/Volume_0859.tgz Volume_0859
# job.batch/mapper860 created
# 861 gs://lpr-g1000-tess/Volume_0860.tgz Volume_0860
# job.batch/mapper861 created
# 862 gs://lpr-g1000-tess/Volume_0861.tgz Volume_0861
# job.batch/mapper862 created
# 863 gs://lpr-g1000-tess/Volume_0862.tgz Volume_0862
# job.batch/mapper863 created
# 864 gs://lpr-g1000-tess/Volume_0863.tgz Volume_0863
# job.batch/mapper864 created
# 865 gs://lpr-g1000-tess/Volume_0864.tgz Volume_0864
# job.batch/mapper865 created
# 866 gs://lpr-g1000-tess/Volume_0865.tgz Volume_0865
# job.batch/mapper866 created
# 867 gs://lpr-g1000-tess/Volume_0866.tgz Volume_0866
# job.batch/mapper867 created
# 868 gs://lpr-g1000-tess/Volume_0867.tgz Volume_0867
# job.batch/mapper868 created
# 869 gs://lpr-g1000-tess/Volume_0868.tgz Volume_0868
# job.batch/mapper869 created
# 870 gs://lpr-g1000-tess/Volume_0869.tgz Volume_0869
# job.batch/mapper870 created
# 871 gs://lpr-g1000-tess/Volume_0870.tgz Volume_0870
# job.batch/mapper871 created
# 872 gs://lpr-g1000-tess/Volume_0871.tgz Volume_0871
# job.batch/mapper872 created
# 873 gs://lpr-g1000-tess/Volume_0872.tgz Volume_0872
# job.batch/mapper873 created
# 874 gs://lpr-g1000-tess/Volume_0873.tgz Volume_0873
# job.batch/mapper874 created
# 875 gs://lpr-g1000-tess/Volume_0874.tgz Volume_0874
# job.batch/mapper875 created
# 876 gs://lpr-g1000-tess/Volume_0875.tgz Volume_0875
# job.batch/mapper876 created
# 877 gs://lpr-g1000-tess/Volume_0876.tgz Volume_0876
# job.batch/mapper877 created
# 878 gs://lpr-g1000-tess/Volume_0877.tgz Volume_0877
# job.batch/mapper878 created
# 879 gs://lpr-g1000-tess/Volume_0878.tgz Volume_0878
# job.batch/mapper879 created
# 880 gs://lpr-g1000-tess/Volume_0879.tgz Volume_0879
# job.batch/mapper880 created
# 881 gs://lpr-g1000-tess/Volume_0880.tgz Volume_0880
# job.batch/mapper881 created
# 882 gs://lpr-g1000-tess/Volume_0881.tgz Volume_0881
# job.batch/mapper882 created
# 883 gs://lpr-g1000-tess/Volume_0882.tgz Volume_0882
# job.batch/mapper883 created
# 884 gs://lpr-g1000-tess/Volume_0883.tgz Volume_0883
# job.batch/mapper884 created
# 885 gs://lpr-g1000-tess/Volume_0884.tgz Volume_0884
# job.batch/mapper885 created
# 886 gs://lpr-g1000-tess/Volume_0885.tgz Volume_0885
# job.batch/mapper886 created
# 887 gs://lpr-g1000-tess/Volume_0886.tgz Volume_0886
# job.batch/mapper887 created
# 888 gs://lpr-g1000-tess/Volume_0887.tgz Volume_0887
# job.batch/mapper888 created
# 889 gs://lpr-g1000-tess/Volume_0888.tgz Volume_0888
# job.batch/mapper889 created
# 890 gs://lpr-g1000-tess/Volume_0889.tgz Volume_0889
# job.batch/mapper890 created
# 891 gs://lpr-g1000-tess/Volume_0890.tgz Volume_0890
# job.batch/mapper891 created
# 892 gs://lpr-g1000-tess/Volume_0891.tgz Volume_0891
# job.batch/mapper892 created
# 893 gs://lpr-g1000-tess/Volume_0892.tgz Volume_0892
# job.batch/mapper893 created
# 894 gs://lpr-g1000-tess/Volume_0893.tgz Volume_0893
# job.batch/mapper894 created
# 895 gs://lpr-g1000-tess/Volume_0894.tgz Volume_0894
# job.batch/mapper895 created
# 896 gs://lpr-g1000-tess/Volume_0895.tgz Volume_0895
# job.batch/mapper896 created
# 897 gs://lpr-g1000-tess/Volume_0896.tgz Volume_0896
# job.batch/mapper897 created
# 898 gs://lpr-g1000-tess/Volume_0897.tgz Volume_0897
# job.batch/mapper898 created
# 899 gs://lpr-g1000-tess/Volume_0898.tgz Volume_0898
# job.batch/mapper899 created
# 900 gs://lpr-g1000-tess/Volume_0899.tgz Volume_0899
# job.batch/mapper900 created
# 901 gs://lpr-g1000-tess/Volume_0900.tgz Volume_0900
# job.batch/mapper901 created
# 902 gs://lpr-g1000-tess/Volume_0901.tgz Volume_0901
# job.batch/mapper902 created
# 903 gs://lpr-g1000-tess/Volume_0902.tgz Volume_0902
# job.batch/mapper903 created
# 904 gs://lpr-g1000-tess/Volume_0903.tgz Volume_0903
# job.batch/mapper904 created
# 905 gs://lpr-g1000-tess/Volume_0904.tgz Volume_0904
# job.batch/mapper905 created
# 906 gs://lpr-g1000-tess/Volume_0905.tgz Volume_0905
# job.batch/mapper906 created
# 907 gs://lpr-g1000-tess/Volume_0906.tgz Volume_0906
# job.batch/mapper907 created
# 908 gs://lpr-g1000-tess/Volume_0907.tgz Volume_0907
# job.batch/mapper908 created
# 909 gs://lpr-g1000-tess/Volume_0908.tgz Volume_0908
# job.batch/mapper909 created
# 910 gs://lpr-g1000-tess/Volume_0909.tgz Volume_0909
# job.batch/mapper910 created
# 911 gs://lpr-g1000-tess/Volume_0910.tgz Volume_0910
# job.batch/mapper911 created
# 912 gs://lpr-g1000-tess/Volume_0911.tgz Volume_0911
# job.batch/mapper912 created
# 913 gs://lpr-g1000-tess/Volume_0912.tgz Volume_0912
# job.batch/mapper913 created
# 914 gs://lpr-g1000-tess/Volume_0913.tgz Volume_0913
# job.batch/mapper914 created
# 915 gs://lpr-g1000-tess/Volume_0914.tgz Volume_0914
# job.batch/mapper915 created
# 916 gs://lpr-g1000-tess/Volume_0915.tgz Volume_0915
# job.batch/mapper916 created
# 917 gs://lpr-g1000-tess/Volume_0916.tgz Volume_0916
# job.batch/mapper917 created
# 918 gs://lpr-g1000-tess/Volume_0917.tgz Volume_0917
# job.batch/mapper918 created
# 919 gs://lpr-g1000-tess/Volume_0918.tgz Volume_0918
# job.batch/mapper919 created
# 920 gs://lpr-g1000-tess/Volume_0919.tgz Volume_0919
# job.batch/mapper920 created
# 921 gs://lpr-g1000-tess/Volume_0920.tgz Volume_0920
# job.batch/mapper921 created
# 922 gs://lpr-g1000-tess/Volume_0921.tgz Volume_0921
# job.batch/mapper922 created
# 923 gs://lpr-g1000-tess/Volume_0922.tgz Volume_0922
# job.batch/mapper923 created
# 924 gs://lpr-g1000-tess/Volume_0923.tgz Volume_0923
# job.batch/mapper924 created
# 925 gs://lpr-g1000-tess/Volume_0924.tgz Volume_0924
# job.batch/mapper925 created
# 926 gs://lpr-g1000-tess/Volume_0925.tgz Volume_0925
# job.batch/mapper926 created
# 927 gs://lpr-g1000-tess/Volume_0926.tgz Volume_0926
# job.batch/mapper927 created
# 928 gs://lpr-g1000-tess/Volume_0927.tgz Volume_0927
# job.batch/mapper928 created
# 929 gs://lpr-g1000-tess/Volume_0928.tgz Volume_0928
# job.batch/mapper929 created
# 930 gs://lpr-g1000-tess/Volume_0929.tgz Volume_0929
# job.batch/mapper930 created
# 931 gs://lpr-g1000-tess/Volume_0930.tgz Volume_0930
# job.batch/mapper931 created
# 932 gs://lpr-g1000-tess/Volume_0931.tgz Volume_0931
# job.batch/mapper932 created
# 933 gs://lpr-g1000-tess/Volume_0932.tgz Volume_0932
# job.batch/mapper933 created
# 934 gs://lpr-g1000-tess/Volume_0933.tgz Volume_0933
# job.batch/mapper934 created
# 935 gs://lpr-g1000-tess/Volume_0934.tgz Volume_0934
# job.batch/mapper935 created
# 936 gs://lpr-g1000-tess/Volume_0935.tgz Volume_0935
# job.batch/mapper936 created
# 937 gs://lpr-g1000-tess/Volume_0936.tgz Volume_0936
# job.batch/mapper937 created
# 938 gs://lpr-g1000-tess/Volume_0937.tgz Volume_0937
# job.batch/mapper938 created
# 939 gs://lpr-g1000-tess/Volume_0938.tgz Volume_0938
# job.batch/mapper939 created
# 940 gs://lpr-g1000-tess/Volume_0939.tgz Volume_0939
# job.batch/mapper940 created
# 941 gs://lpr-g1000-tess/Volume_0940.tgz Volume_0940
# job.batch/mapper941 created
# 942 gs://lpr-g1000-tess/Volume_0941.tgz Volume_0941
# job.batch/mapper942 created
# 943 gs://lpr-g1000-tess/Volume_0942.tgz Volume_0942
# job.batch/mapper943 created
# 944 gs://lpr-g1000-tess/Volume_0943.tgz Volume_0943
# job.batch/mapper944 created
# 945 gs://lpr-g1000-tess/Volume_0944.tgz Volume_0944
# job.batch/mapper945 created
# 946 gs://lpr-g1000-tess/Volume_0945.tgz Volume_0945
# job.batch/mapper946 created
# 947 gs://lpr-g1000-tess/Volume_0946.tgz Volume_0946
# job.batch/mapper947 created
# 948 gs://lpr-g1000-tess/Volume_0947.tgz Volume_0947
# job.batch/mapper948 created
# 949 gs://lpr-g1000-tess/Volume_0948.tgz Volume_0948
# job.batch/mapper949 created
# 950 gs://lpr-g1000-tess/Volume_0949.tgz Volume_0949
# job.batch/mapper950 created
# 951 gs://lpr-g1000-tess/Volume_0950.tgz Volume_0950
# job.batch/mapper951 created
# 952 gs://lpr-g1000-tess/Volume_0951.tgz Volume_0951
# job.batch/mapper952 created
# 953 gs://lpr-g1000-tess/Volume_0952.tgz Volume_0952
# job.batch/mapper953 created
# 954 gs://lpr-g1000-tess/Volume_0953.tgz Volume_0953
# job.batch/mapper954 created
# 955 gs://lpr-g1000-tess/Volume_0954.tgz Volume_0954
# job.batch/mapper955 created
# 956 gs://lpr-g1000-tess/Volume_0955.tgz Volume_0955
# job.batch/mapper956 created
# 957 gs://lpr-g1000-tess/Volume_0956.tgz Volume_0956
# job.batch/mapper957 created
# 958 gs://lpr-g1000-tess/Volume_0957.tgz Volume_0957
# job.batch/mapper958 created
# 959 gs://lpr-g1000-tess/Volume_0958.tgz Volume_0958
# job.batch/mapper959 created
# 960 gs://lpr-g1000-tess/Volume_0959.tgz Volume_0959
# job.batch/mapper960 created
# 961 gs://lpr-g1000-tess/Volume_0960.tgz Volume_0960
# job.batch/mapper961 created
# 962 gs://lpr-g1000-tess/Volume_0961.tgz Volume_0961
# job.batch/mapper962 created
# 963 gs://lpr-g1000-tess/Volume_0962.tgz Volume_0962
# job.batch/mapper963 created
# 964 gs://lpr-g1000-tess/Volume_0963.tgz Volume_0963
# job.batch/mapper964 created
# 965 gs://lpr-g1000-tess/Volume_0964.tgz Volume_0964
# job.batch/mapper965 created
# 966 gs://lpr-g1000-tess/Volume_0965.tgz Volume_0965
# job.batch/mapper966 created
# 967 gs://lpr-g1000-tess/Volume_0966.tgz Volume_0966
# job.batch/mapper967 created
# 968 gs://lpr-g1000-tess/Volume_0967.tgz Volume_0967
# job.batch/mapper968 created
# 969 gs://lpr-g1000-tess/Volume_0968.tgz Volume_0968
# job.batch/mapper969 created
# 970 gs://lpr-g1000-tess/Volume_0969.tgz Volume_0969
# job.batch/mapper970 created
# 971 gs://lpr-g1000-tess/Volume_0970.tgz Volume_0970
# job.batch/mapper971 created
# 972 gs://lpr-g1000-tess/Volume_0971.tgz Volume_0971
# job.batch/mapper972 created
# 973 gs://lpr-g1000-tess/Volume_0972.tgz Volume_0972
# job.batch/mapper973 created
# 974 gs://lpr-g1000-tess/Volume_0973.tgz Volume_0973
# job.batch/mapper974 created
# 975 gs://lpr-g1000-tess/Volume_0974.tgz Volume_0974
# job.batch/mapper975 created
# 976 gs://lpr-g1000-tess/Volume_0975.tgz Volume_0975
# job.batch/mapper976 created
# 977 gs://lpr-g1000-tess/Volume_0976.tgz Volume_0976
# job.batch/mapper977 created
# 978 gs://lpr-g1000-tess/Volume_0977.tgz Volume_0977
# job.batch/mapper978 created
# 979 gs://lpr-g1000-tess/Volume_0978.tgz Volume_0978
# job.batch/mapper979 created
# 980 gs://lpr-g1000-tess/Volume_0979.tgz Volume_0979
# job.batch/mapper980 created
# 981 gs://lpr-g1000-tess/Volume_0980.tgz Volume_0980
# job.batch/mapper981 created
# 982 gs://lpr-g1000-tess/Volume_0981.tgz Volume_0981
# job.batch/mapper982 created
# 983 gs://lpr-g1000-tess/Volume_0982.tgz Volume_0982
# job.batch/mapper983 created
# 984 gs://lpr-g1000-tess/Volume_0983.tgz Volume_0983
# job.batch/mapper984 created
# 985 gs://lpr-g1000-tess/Volume_0984.tgz Volume_0984
# job.batch/mapper985 created
# 986 gs://lpr-g1000-tess/Volume_0985.tgz Volume_0985
# job.batch/mapper986 created
# 987 gs://lpr-g1000-tess/Volume_0986.tgz Volume_0986
# job.batch/mapper987 created
# 988 gs://lpr-g1000-tess/Volume_0987.tgz Volume_0987
# job.batch/mapper988 created
# 989 gs://lpr-g1000-tess/Volume_0988.tgz Volume_0988
# job.batch/mapper989 created
# 990 gs://lpr-g1000-tess/Volume_0989.tgz Volume_0989
# job.batch/mapper990 created
# 991 gs://lpr-g1000-tess/Volume_0990.tgz Volume_0990
# job.batch/mapper991 created
# 992 gs://lpr-g1000-tess/Volume_0991.tgz Volume_0991
# job.batch/mapper992 created
# 993 gs://lpr-g1000-tess/Volume_0992.tgz Volume_0992
# job.batch/mapper993 created
# 994 gs://lpr-g1000-tess/Volume_0993.tgz Volume_0993
# job.batch/mapper994 created
# 995 gs://lpr-g1000-tess/Volume_0994.tgz Volume_0994
# job.batch/mapper995 created
# 996 gs://lpr-g1000-tess/Volume_0995.tgz Volume_0995
# job.batch/mapper996 created
# 997 gs://lpr-g1000-tess/Volume_0996.tgz Volume_0996
# job.batch/mapper997 created
# 998 gs://lpr-g1000-tess/Volume_0997.tgz Volume_0997
# job.batch/mapper998 created
# 999 gs://lpr-g1000-tess/Volume_0998.tgz Volume_0998
# job.batch/mapper999 created
# 1000 gs://lpr-g1000-tess/Volume_0999.tgz Volume_0999
# job.batch/mapper1000 created

# %%
sleep 60

# %%
kubectl logs job.batch/mapper1 | tail
# Out:
# Volume_0000/Image_0510
# Volume_0000/Image_0511
# Volume_0000/Image_0512
# Volume_0000/Image_0513
# Volume_0000/Image_0514
# Volume_0000/Image_0515
# Volume_0000/Image_0516
# Volume_0000/Image_0517
# / [1 files][    0.0 B/    0.0 B]      0.0 B/s
# Operation completed over 1 objects.

# %%
kubectl wait jobs -l jobgroup=mapper --for=condition=complete --timeout=-1s
# Out:
# job.batch/mapper1 condition met
# job.batch/mapper10 condition met
# job.batch/mapper100 condition met
# job.batch/mapper1000 condition met
# job.batch/mapper101 condition met
# job.batch/mapper102 condition met
# job.batch/mapper103 condition met
# job.batch/mapper104 condition met
# job.batch/mapper105 condition met
# job.batch/mapper106 condition met
# job.batch/mapper107 condition met
# job.batch/mapper108 condition met
# job.batch/mapper109 condition met
# job.batch/mapper11 condition met
# job.batch/mapper110 condition met
# job.batch/mapper111 condition met
# job.batch/mapper112 condition met
# job.batch/mapper113 condition met
# job.batch/mapper114 condition met
# job.batch/mapper115 condition met
# job.batch/mapper116 condition met
# job.batch/mapper117 condition met
# job.batch/mapper118 condition met
# job.batch/mapper119 condition met
# job.batch/mapper12 condition met
# job.batch/mapper120 condition met
# job.batch/mapper121 condition met
# job.batch/mapper122 condition met
# job.batch/mapper123 condition met
# job.batch/mapper124 condition met
# job.batch/mapper125 condition met
# job.batch/mapper126 condition met
# job.batch/mapper127 condition met
# job.batch/mapper128 condition met
# job.batch/mapper129 condition met
# job.batch/mapper13 condition met
# job.batch/mapper130 condition met
# job.batch/mapper131 condition met
# job.batch/mapper132 condition met
# job.batch/mapper133 condition met
# job.batch/mapper134 condition met
# job.batch/mapper135 condition met
# job.batch/mapper136 condition met
# job.batch/mapper137 condition met
# job.batch/mapper138 condition met
# job.batch/mapper139 condition met
# job.batch/mapper14 condition met
# job.batch/mapper140 condition met
# job.batch/mapper141 condition met
# job.batch/mapper142 condition met
# job.batch/mapper143 condition met
# job.batch/mapper144 condition met
# job.batch/mapper145 condition met
# job.batch/mapper146 condition met
# job.batch/mapper147 condition met
# job.batch/mapper148 condition met
# job.batch/mapper149 condition met
# job.batch/mapper15 condition met
# job.batch/mapper150 condition met
# job.batch/mapper151 condition met
# job.batch/mapper152 condition met
# job.batch/mapper153 condition met
# job.batch/mapper154 condition met
# job.batch/mapper155 condition met
# job.batch/mapper156 condition met
# job.batch/mapper157 condition met
# job.batch/mapper158 condition met
# job.batch/mapper159 condition met
# job.batch/mapper16 condition met
# job.batch/mapper160 condition met
# job.batch/mapper161 condition met
# job.batch/mapper162 condition met
# job.batch/mapper163 condition met
# job.batch/mapper164 condition met
# job.batch/mapper165 condition met
# job.batch/mapper166 condition met
# job.batch/mapper167 condition met
# job.batch/mapper168 condition met
# job.batch/mapper169 condition met
# job.batch/mapper17 condition met
# job.batch/mapper170 condition met
# job.batch/mapper171 condition met
# job.batch/mapper172 condition met
# job.batch/mapper173 condition met
# job.batch/mapper174 condition met
# job.batch/mapper175 condition met
# job.batch/mapper176 condition met
# job.batch/mapper177 condition met
# job.batch/mapper178 condition met
# job.batch/mapper179 condition met
# job.batch/mapper18 condition met
# job.batch/mapper180 condition met
# job.batch/mapper181 condition met
# job.batch/mapper182 condition met
# job.batch/mapper183 condition met
# job.batch/mapper184 condition met
# job.batch/mapper185 condition met
# job.batch/mapper186 condition met
# job.batch/mapper187 condition met
# job.batch/mapper188 condition met
# job.batch/mapper189 condition met
# job.batch/mapper19 condition met
# job.batch/mapper190 condition met
# job.batch/mapper191 condition met
# job.batch/mapper192 condition met
# job.batch/mapper193 condition met
# job.batch/mapper194 condition met
# job.batch/mapper195 condition met
# job.batch/mapper196 condition met
# job.batch/mapper197 condition met
# job.batch/mapper198 condition met
