# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import glob
import PIL
import webdataset as wds
import os
import os.path
import io
from ocrlib import extract_seg
from random import randrange
import re
import sys
import scipy.ndimage as ndi
from lxml import html

# %%
def get_text(node):
    textnodes = node.xpath('.//text()')
    s = ''.join([text for text in textnodes])
    return re.sub(r'\s+', ' ', s)


def get_prop(node, name):
    title = node.get("title")
    props = title.split(';')
    for prop in props:
        (key, args) = prop.split(None, 1)
        args = args.strip('"')
        if key == name:
            return args
    return None

# %%
src = iter(wds.Dataset("uw3/uw3-hocr.tar").decode())

# %%
for i, sample in enumerate(src):
    break
sample.keys()
imshow(sample["page.jpg"])

# %%
sample["hocr.html"]
# Out:
# b"<html>\n<head>\n<meta name='langs' content='English'>\n<meta name='scripts' content='Roman'>\n<meta name='character_orientation' content='up-right'>\n<meta name='degradation_type' content='photocopy'>\n<meta name='document_type' content='journal'>\n<meta name='publication_name' content='Continuum Mechanics and Thermodynamics'>\n<meta name='publication_date' content='November 89'>\n<meta name='page_id' content='A001'>\n<meta name='page_number' content='283'>\n<meta name='text_reading_direction' content='left-right'>\n<meta name='displayed_math_present' content='N'>\n<meta name='dominant_font_type' content='serif'>\n<meta name='dominant_font_style' content='plain'>\n<meta name='dominant_font_spacing' content='proportional'>\n<meta name='dominant_font_size' content='9-12'>\n<meta name='drawing_present' content='N'>\n<meta name='extras_top_edge' content='Y'>\n<meta name='extras_left_edge' content='Y'>\n<meta name='extras_right_edge' content='Y'>\n<meta name='extras_bottom_edge' content='Y'>\n<meta name='header_present' content='Y'>\n<meta name='footer_present' content='N'>\n<meta name='issue_number' content='4'>\n<meta name='half_tone_present' content='N'>\n<meta name='horizontal_streaks' content='N'>\n<meta name='vertical_streaks' content='N'>\n<meta name='max_columns_number' content='1'>\n<meta name='nth_copy' content='1'>\n<meta name='multiple_pages' content='N'>\n<meta name='left_edge_skewed' content='N'>\n<meta name='left_edge_smeared' content='None'>\n<meta name='right_edge_skewed' content='N'>\n<meta name='right_edge_smeared' content='None'>\n<meta name='page_layout' content='regular'>\n<meta name='rotation_degree' content='-0.03'>\n<meta name='salt_pepper' content='N'>\n<meta name='text_zone_present' content='Y'>\n<meta name='table_zone_present' content='N'>\n<meta name='volume_number' content='1'>\n<meta name='standard_deviation' content='0.07'>\n<meta name='special_symbols_present' content='Y'>\n<title>Ground Truth</title>\n</head>\n<body>\n<div class='ocr_page' title='txt file /data/datasets/uw/uw3/ENGLISH/LINEWORD/DAFS/A001.TXT'>\n<div class='ocr-header' size='9-12' align='justified' face='serif' style='plain' lan='English' dir='left-right' id='000'>\n<span class='ocr_line' title='bbox 799 195 1601 232'>Continuum Mech. Thermodyn. 1 (1989) 283-303</span>\n</div>\n<div class='ocr-header' size='13-18' align='justified' face='serif' style='bold' lan='English' dir='left-right' id='001'>\n<span class='ocr_line' title='bbox 1821 168 2222 220'>Continuum Mechanics</span>\n<span class='ocr_line' title='bbox 1892 223 1931 254'>and</span>\n<span class='ocr_line' title='bbox 1821 241 2131 303'>Thermodynamics</span>\n</div>\n<div class='ocr-header' size='9-12' align='justified' face='serif' style='plain' lan='English' dir='left-right' id='002'>\n<span class='ocr_line' title='bbox 1825 320 2222 356'>\\copyright Springer-Verlag 1989</span>\n</div>\n<div class='ocr-title' size='13-18' align='justified' face='serif' style='bold' lan='English' dir='left-right' id='003'>\n<span class='ocr_line' title='bbox 797 795 1845 851'>A mathematical model for the hysteresis</span>\n<span class='ocr_line' title='bbox 798 859 1406 914'>in shape memory alloys</span>\n</div>\n<div class='ocr-author' size='9-12' align='justified' face='serif' style='bold' lan='English' dir='left-right' id='004'>\n<span class='ocr_line' title='bbox 792 976 1075 1015'>Yongzhong Huo</span>\n</div>\n<div class='ocr-abstract' size='9-12' align='justified' face='serif' style='plain' lan='English' dir='left-right' id='005'>\n<span class='ocr_line' title='bbox 860 1119 2241 1161'>The Preisach Model for ferromagnets is generalized and adapted for the</span>\n<span class='ocr_line' title='bbox 861 1168 2240 1211'>description of the hysteretic behaviour of a polycrystalline specimen of shape-</span>\n<span class='ocr_line' title='bbox 861 1217 2241 1260'>memory alloys. The thermodynamical properties of the individual crystallites</span>\n<span class='ocr_line' title='bbox 861 126 ...

# %%
def extract_boxes(page, boxes, pad=5):
    #for y0, y1, x0, x1 in boxes:
    for x0, y0, x1, y1 in boxes:
        h, w = y1-y0, x1-x0
        word = ndi.affine_transform(page, np.eye(3), output_shape=(h+2*pad, w+2*pad, 3), offset=(y0-pad, x0-pad, 0), order=0)
        yield word

# %%
def get_lines(hocr):
    doc = html.parse(io.StringIO(hocr))
    for line in doc.xpath("//*[@class='ocr_line']"):
        text = get_text(line)
        bbox = [int(x) for x in get_prop(line, "bbox").split()]
        yield (bbox, text)
        #print(re.sub(r'\s+', '\x20', line.text_content()).strip())
        
lines = list(get_lines(sample["hocr.html"].decode("utf-8")))
images = list(extract_boxes(sample["page.jpg"], [x[0] for x in lines]))

# %%
imshow(images[10])
print(lines[10])
# Out:
# ([861, 1217, 2241, 1260], 'memory alloys. The thermodynamical properties of the individual crystallites')

# %%
sink = wds.TarWriter("uw3/uw3-rawlines.tar")
fcount = 0
for i, sample in enumerate(wds.Dataset("uw3/uw3-hocr.tar").decode()):
    key = sample["__key__"]
    if fcount%100==0:
        print(fcount, key)
    lines = list(get_lines(sample["hocr.html"].decode("utf-8")))
    images = list(extract_boxes(sample["page.jpg"], [x[0] for x in lines]))
    assert len(lines) == len(images)
    count = 0
    for (bbox, txt), image in zip(lines, images):
        count += 1
        result = {
            "__key__": f"{key}-{count}",
            "bbox.json": bbox,
            "gt.txt": txt,
            "line.png": image
        }
        sink.write(result)
    fcount += 1
sink.close()
# Out:
# 0 A001
# 100 A063
# 200 D038
# 300 E009
# 400 E048
# 500 H048
# 600 IG0F
# 700 K00F
# 800 N04L
# 900 S02N
# 1000 W020
# 1100 W0C3
# 1200 W0L3
# 1300 W114
# 1400 W1B1
# 1500 W1K2

# %%
# !tarp cat -s 20000 uw3/uw3-rawlines.tar -o - | tarp split -c 5000 - -o uw3/uw3-rawlines-%06d.tar
# Out:
# [progress] # source -
# [info] # shuffle 20000
# [progress] # writing -
# [progress] # source uw3/uw3-rawlines.tar
# [progress] # shard uw3/uw3-rawlines-000000.tar
# [progress] # shard uw3/uw3-rawlines-000001.tar
# [progress] # shard uw3/uw3-rawlines-000002.tar
# [progress] # shard uw3/uw3-rawlines-000003.tar
# [progress] # shard uw3/uw3-rawlines-000004.tar
# [progress] # shard uw3/uw3-rawlines-000005.tar
# [progress] # shard uw3/uw3-rawlines-000006.tar
# [progress] # shard uw3/uw3-rawlines-000007.tar
# [progress] # shard uw3/uw3-rawlines-000008.tar
# [progress] # shard uw3/uw3-rawlines-000009.tar
# [progress] # shard uw3/uw3-rawlines-000010.tar
# [progress] # shard uw3/uw3-rawlines-000011.tar
# [progress] # shard uw3/uw3-rawlines-000012.tar
# [progress] # shard uw3/uw3-rawlines-000013.tar
# [progress] # shard uw3/uw3-rawlines-000014.tar
# [progress] # shard uw3/uw3-rawlines-000015.tar
# [progress] # shard uw3/uw3-rawlines-000016.tar
# [progress] # shard uw3/uw3-rawlines-000017.tar
# [progress] # shard uw3/uw3-rawlines-000018.tar
# [progress] # shard uw3/uw3-rawlines-000019.tar
# [progress] # shard uw3/uw3-rawlines-000020.tar
# [progress] # shard uw3/uw3-rawlines-000021.tar
