# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import torch
from torch import nn
from ocrlib import ocrhelpers, ocrmodels

# %%
model = ocrmodels.make("seg_lstm")
model.load_state_dict(torch.load("models/"))
# Out:
# <All keys matched successfully>

# %%
image = torch.load("_0028_pred.dump")
imshow(image)
figsize(10, 10)

# %%
train = torch.load("_0004_train.dump")
imshow(train[0][0])

# %%
import numpy as np

# %%
np.random.uniform(1, 2, size=(5, 5))
# Out:
# array([[1.49749572, 1.27772419, 1.22647231, 1.61795529, 1.7237559 ],
#        [1.41889188, 1.61085013, 1.65336556, 1.08255858, 1.25363544],
#        [1.34907372, 1.25870852, 1.66529068, 1.31114521, 1.3892744 ],
#        [1.65544816, 1.51158613, 1.52920127, 1.3607783 , 1.34229599],
#        [1.90041312, 1.3198533 , 1.03411164, 1.2375102 , 1.39226869]])
